# %%
import pandas as pd

# %%
# !ls data
# Out:
# bom.movie_gross.csv  title.akas.csv	   title.ratings.csv
# name.basics.csv      title.basics.csv	   tmdb.movies.csv
# rt.movie_info.tsv    title.crew.csv	   tn.movie_budgets.csv
# rt.reviews.tsv	     title.principals.csv

# %%
# Title, Studio, Domestic Gross, Foreign Gross, Year
movie_gross_df = pd.read_csv('data/bom.movie_gross.csv')

# Name variable (nconst), Name of Crew/Principal, Primary Profession, Known for Titles (tconst)
people_info_df = pd.read_csv('data/name.basics.csv')

# ID, Rating, Genre, Director, Writer, Theater Date, Box Office, Runtime, Studio
rt_movie_info_df = pd.read_csv('data/rt.movie_info.tsv', delimiter='\t')

# ID, Rating, Fresh, Top Critic
rt_movie_reviews_df = pd.read_csv('data/rt.reviews.tsv', delimiter='\t', encoding='latin1')

# Title ID, Title, Region, Language
title_akas_df = pd.read_csv('data/title.akas.csv')

# Title ID (tconst), Primary Title, Original Title, Year, Runtime, Genres
title_basics_df = pd.read_csv('data/title.basics.csv')

# Title ID (tconst), Directors (nconst), Writers (nconst)
title_crew_df = pd.read_csv('data/title.crew.csv')

# Title ID (tconst), People (nconst), Category (primary profession)
title_principals_df = pd.read_csv('data/title.principals.csv')

# Titled ID (tconst), Rating, Num Votes
title_ratings_df = pd.read_csv('data/title.ratings.csv')

# Genre, Language, Original Title, Popularity, Date, Title, Average Rating, Num of Ratings
tmdb_movies_df = pd.read_csv('data/tmdb.movies.csv')

# Release Date, Title, Budget, Domestic Gross, Worldwide Gross
movie_budgets_df = pd.read_csv('data/tn.movie_budgets.csv')

# %% [markdown]
# Matt is going to work on joining any of the dataframes with the tconst or nconst variables.
#
# Grace will work on joining the Rotten Tomatoes dataframes.
#
# Jeff will work on joining the rest.

# %% [markdown]
# Matt's dataframes:
#
# people_info_df
#
# title_akas_df
#
# title_basics_df
#
# title_crew_df
#
# title_principals_df
#
# title_ratings_df

# %%
title_principals_df.groupby('tconst').count()
# Out:
#            ordering  nconst  category  job  characters
# tconst
# tt0063540        10      10        10    4           4
# tt0066787         7       7         7    1           3
# tt0069049        10      10        10    2           4
# tt0069204        10      10        10    1           5
# tt0100275        10      10        10    4           0
# ...             ...     ...       ...  ...         ...
# tt9916538        10      10        10    5           4
# tt9916622        10      10        10    3           4
# tt9916706        10      10        10    1           0
# tt9916730         9       9         9    2           0
# tt9916754        10      10        10    2           4
#
# [143454 rows x 5 columns]

# %%
# Should the principals merge be a join?
# merge1_df = title_principals_df.merge(title_akas_df, how='left', left_on='tconst', right_on='title_id')
# merge1_df

# %%
# merge1_df = title_principals_df.join(title_akas_df, how='left', lsuffix='tconst', rsuffix='title_id')
# merge1_df

# %%
print(people_info_df.columns)

print(title_akas_df.columns)

print(title_basics_df.columns)

print(title_crew_df.columns)

print(title_principals_df.columns)

print(title_ratings_df.columns)
# Out:
# Index(['nconst', 'primary_name', 'birth_year', 'death_year',
#        'primary_profession', 'known_for_titles'],
#       dtype='object')
# Index(['title_id', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'is_original_title'],
#       dtype='object')
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')
# Index(['tconst', 'directors', 'writers'], dtype='object')
# Index(['tconst', 'ordering', 'nconst', 'category', 'job', 'characters'], dtype='object')
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
print(people_info_df.shape)

print(title_akas_df.shape)

print(title_basics_df.shape)

print(title_crew_df.shape)

print(title_principals_df.shape)

print(title_ratings_df.shape)
# Out:
# (606648, 6)
# (331703, 8)
# (146144, 6)
# (146144, 3)
# (1028186, 6)
# (73856, 3)

# %%
print(people_info_df.shape)

print(len(pd.unique(title_akas_df['title_id'])))

print(len(pd.unique(title_basics_df['tconst'])))

print(len(pd.unique(title_crew_df['tconst'])))

print(len(pd.unique(title_principals_df['tconst'])))

print(len(pd.unique(title_ratings_df['tconst'])))
# Out:
# (606648, 6)
# 122302
# 146144
# 146144
# 143454
# 73856

# %%
first_join = title_basics_df.merge(title_crew_df, how='left', left_on='tconst', right_on='tconst')
first_join
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres            directors  \
# 0                 175.0    Action,Crime,Drama            nm0712540
# 1                 114.0       Biography,Drama            nm0002411
# 2                 122.0                 Drama            nm0000080
# 3                   NaN          Comedy,Drama            nm0611531
# 4                  80.0  Comedy,Drama,Fantasy  nm0765384,nm0749914
# ...                 ...                   ...                  ...
# 146139            123.0                 Drama            nm8185151
# 146140              NaN           Documentary  nm9272490,nm9272491
# 146141              NaN                Comedy            nm7764440
# 146142            116.0                   NaN           nm10538612
# 146143              NaN           Documentary  nm9272490,nm8349149
#
#                                         writers
# 0       nm0023551,nm1194313,nm0347899,nm1391276
# 1                                           NaN
# 2                           nm0000080,nm0462648
# 3                                     nm0347899
# 4                           nm1360635,nm0749914
# ...                                         ...
# 146139            nm4843252,nm4900525,nm2679404
# 146140                      nm9272490,nm9272491
# 146141                                nm7933903
# 146142                               nm10538612
# 146143                      nm8349149,nm9272490
#
# [146144 rows x 8 columns]

# %%
second_join = first_join.merge(title_principals_df, how='left', left_on='tconst', right_on='tconst')
second_join
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 1030871  tt9916754  Chico Albuquerque - Revelações
# 1030872  tt9916754  Chico Albuquerque - Revelações
# 1030873  tt9916754  Chico Albuquerque - Revelações
# 1030874  tt9916754  Chico Albuquerque - Revelações
# 1030875  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# 4                             Sunghursh        2013            175.0
# ...                                 ...         ...              ...
# 1030871  Chico Albuquerque - Revelações        2013              NaN
# 1030872  Chico Albuquerque - Revelações        2013              NaN
# 1030873  Chico Albuquerque - Revelações        2013              NaN
# 1030874  Chico Albuquerque - Revelações        2013              NaN
# 1030875  Chico Albuquerque - Revelações        2013              NaN
#
#                      genres            directors  \
# 0        Action,Crime,Drama            nm0712540
# 1        Action,Crime,Drama            nm0712540
# 2        Action,Crime,Drama            nm0712540
# 3        Action,Crime,Drama            nm0712540
# 4        Action,Crime,Drama            nm0712540
# ...                     ...                  ...
# 1030871         Documentary  nm9272490,nm8349149
# 1030872         Documentary  nm9272490,nm8349149
# 1030873         Documentary  nm9272490,nm8349149
# 1030874         Documentary  nm9272490,nm8349149
# 1030875         Documentary  nm9272490,nm8349149
#
#                                          writers  ordering      nconst  \
# 0        nm0023551,nm1194313,nm0347899,nm1391276      10.0   nm0006210
# 1        nm0023551,nm1194313,nm0347899,nm1391276       1.0   nm0474801
# 2        nm0023551,nm1194313,nm0347899,nm1391276       2.0   nm0904537
# 3        nm0023551,nm1194313,nm0347899,nm1391276       3.0   nm0756379
# 4        nm0023551,nm1194313,nm0347899,nm1391276       4.0   nm0474876
# ...                                          ...       ...         ...
# 1030871                      nm8349149,nm9272490       5.0   nm9272490
# 1030872                      nm8349149,nm9272490       6.0   nm8349149
# 1030873                      nm8349149,nm9272490       7.0   nm9272489
# 1030874                      nm8349149,nm9272490       8.0  nm10538638
# 1030875                      nm8349149,nm9272490       9.0  nm10538635
#
#                 category                   job  \
# 0               composer                   NaN
# 1                  actor                   NaN
# 2                actress                   NaN
# 3                  actor                   NaN
# 4                  actor                   NaN
# ...                  ...                   ...
# 1030871         director  supervising director
# 1030872         director           co-director
# 1030873  cinematographer                   NaN
# 1030874  cinematographer                   NaN
# 1030875  cinematographer                   NaN
#
#                               characters
# 0                                    NaN
# 1        ["Kundan S. Prasad","Bajrangi"]
# 2            ["Munni","Laila-E-Aasmaan"]
# 3                  ["Ganeshi N. Prasad"]
# 4                   ["Dwarka N. Prasad"]
# ...                                  ...
# 1030871                              NaN
# 1030872                              NaN
# 1030873                              NaN
# 1030874                              NaN
# 1030875                              NaN
#
# [1030876 rows x 13 columns]

# %%
third_join = second_join.merge(title_ratings_df, how='left', left_on='tconst', right_on='tconst')
third_join
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 1030871  tt9916754  Chico Albuquerque - Revelações
# 1030872  tt9916754  Chico Albuquerque - Revelações
# 1030873  tt9916754  Chico Albuquerque - Revelações
# 1030874  tt9916754  Chico Albuquerque - Revelações
# 1030875  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# 4                             Sunghursh        2013            175.0
# ...                                 ...         ...              ...
# 1030871  Chico Albuquerque - Revelações        2013              NaN
# 1030872  Chico Albuquerque - Revelações        2013              NaN
# 1030873  Chico Albuquerque - Revelações        2013              NaN
# 1030874  Chico Albuquerque - Revelações        2013              NaN
# 1030875  Chico Albuquerque - Revelações        2013              NaN
#
#                      genres            directors  \
# 0        Action,Crime,Drama            nm0712540
# 1        Action,Crime,Drama            nm0712540
# 2        Action,Crime,Drama            nm0712540
# 3        Action,Crime,Drama            nm0712540
# 4        Action,Crime,Drama            nm0712540
# ...                     ...                  ...
# 1030871         Documentary  nm9272490,nm8349149
# 1030872         Documentary  nm9272490,nm8349149
# 1030873         Documentary  nm9272490,nm8349149
# 1030874         Documentary  nm9272490,nm8349149
# 1030875         Documentary  nm9272490,nm8349149
#
#                                          writers  ordering      nconst  \
# 0        nm0023551,nm1194313,nm0347899,nm1391276      10.0   nm0006210
# 1        nm0023551,nm1194313,nm0347899,nm1391276       1.0   nm0474801
# 2        nm0023551,nm1194313,nm0347899,nm1391276       2.0   nm0904537
# 3        nm0023551,nm1194313,nm0347899,nm1391276       3.0   nm0756379
# 4        nm0023551,nm1194313,nm0347899,nm1391276       4.0   nm0474876
# ...                                          ...       ...         ...
# 1030871                      nm8349149,nm9272490       5.0   nm9272490
# 1030872                      nm8349149,nm9272490       6.0   nm8349149
# 1030873                      nm8349149,nm9272490       7.0   nm9272489
# 1030874                      nm8349149,nm9272490       8.0  nm10538638
# 1030875                      nm8349149,nm9272490       9.0  nm10538635
#
#                 category                   job  \
# 0               composer                   NaN
# 1                  actor                   NaN
# 2                actress                   NaN
# 3                  actor                   NaN
# 4                  actor                   NaN
# ...                  ...                   ...
# 1030871         director  supervising director
# 1030872         director           co-director
# 1030873  cinematographer                   NaN
# 1030874  cinematographer                   NaN
# 1030875  cinematographer                   NaN
#
#                               characters  averagerating  numvotes
# 0                                    NaN            7.0      77.0
# 1        ["Kundan S. Prasad","Bajrangi"]            7.0      77.0
# 2            ["Munni","Laila-E-Aasmaan"]            7.0      77.0
# 3                  ["Ganeshi N. Prasad"]            7.0      77.0
# 4                   ["Dwarka N. Prasad"]            7.0      77.0
# ...                                  ...            ...       ...
# 1030871                              NaN            NaN       NaN
# 1030872                              NaN            NaN       NaN
# 1030873                              NaN            NaN       NaN
# 1030874                              NaN            NaN       NaN
# 1030875                              NaN            NaN       NaN
#
# [1030876 rows x 15 columns]

# %%
fourth_join = third_join.merge(title_akas_df, how='left', left_on='tconst', right_on='title_id')
fourth_join
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 2975780  tt9916754  Chico Albuquerque - Revelações
# 2975781  tt9916754  Chico Albuquerque - Revelações
# 2975782  tt9916754  Chico Albuquerque - Revelações
# 2975783  tt9916754  Chico Albuquerque - Revelações
# 2975784  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# 4                             Sunghursh        2013            175.0
# ...                                 ...         ...              ...
# 2975780  Chico Albuquerque - Revelações        2013              NaN
# 2975781  Chico Albuquerque - Revelações        2013              NaN
# 2975782  Chico Albuquerque - Revelações        2013              NaN
# 2975783  Chico Albuquerque - Revelações        2013              NaN
# 2975784  Chico Albuquerque - Revelações        2013              NaN
#
#                      genres            directors  \
# 0        Action,Crime,Drama            nm0712540
# 1        Action,Crime,Drama            nm0712540
# 2        Action,Crime,Drama            nm0712540
# 3        Action,Crime,Drama            nm0712540
# 4        Action,Crime,Drama            nm0712540
# ...                     ...                  ...
# 2975780         Documentary  nm9272490,nm8349149
# 2975781         Documentary  nm9272490,nm8349149
# 2975782         Documentary  nm9272490,nm8349149
# 2975783         Documentary  nm9272490,nm8349149
# 2975784         Documentary  nm9272490,nm8349149
#
#                                          writers  ordering_x      nconst  ...  \
# 0        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 1        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 2        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 3        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 4        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# ...                                          ...         ...         ...  ...
# 2975780                      nm8349149,nm9272490         5.0   nm9272490  ...
# 2975781                      nm8349149,nm9272490         6.0   nm8349149  ...
# 2975782                      nm8349149,nm9272490         7.0   nm9272489  ...
# 2975783                      nm8349149,nm9272490         8.0  nm10538638  ...
# 2975784                      nm8349149,nm9272490         9.0  nm10538635  ...
#
#         averagerating numvotes   title_id  ordering_y      title region  \
# 0                 7.0     77.0  tt0063540         1.0  Sangharsh     IN
# 1                 7.0     77.0  tt0063540         2.0  Sunghursh    NaN
# 2                 7.0     77.0  tt0063540         3.0  Sunghursh     IN
# 3                 7.0     77.0  tt0063540         4.0  Sunghursh     IN
# 4                 7.0     77.0  tt0063540         5.0  Sungharsh     IN
# ...               ...      ...        ...         ...        ...    ...
# 2975780           NaN      NaN        NaN         NaN        NaN    NaN
# 2975781           NaN      NaN        NaN         NaN        NaN    NaN
# 2975782           NaN      NaN        NaN         NaN        NaN    NaN
# 2975783           NaN      NaN        NaN         NaN        NaN    NaN
# 2975784           NaN      NaN        NaN         NaN        NaN    NaN
#
#          language     types                   attributes is_original_title
# 0              hi       NaN  alternative transliteration               0.0
# 1             NaN  original                          NaN               1.0
# 2             NaN       NaN                          NaN               0.0
# 3              hi       NaN  alternative transliteration               0.0
# 4              hi       NaN         alternative spelling               0.0
# ...           ...       ...                          ...               ...
# 2975780       NaN       NaN                          NaN               NaN
# 2975781       NaN       NaN                          NaN               NaN
# 2975782       NaN       NaN                          NaN               NaN
# 2975783       NaN       NaN                          NaN               NaN
# 2975784       NaN       NaN                          NaN               NaN
#
# [2975785 rows x 23 columns]

# %%
fourth_join['title_id'].isna().sum()
# Out:
# 134509

# %%
fourth_join.groupby('original_title').count()
# Out:
#                                     tconst  primary_title  start_year  \
# original_title
# #1 Serial Killer                        30             30          30
# #5                                       9              9           9
# #50Fathers                               9              9           9
# #66                                     10             10          10
# #82 Summits                              5              5           5
# ...                                    ...            ...         ...
# ärtico                                  50             50          50
# è solo questione di punti di vista       8              8           8
# è solo questione di tempo               15             15          15
# élèctions piege à cons                   6              6           6
# împetu                                   4              4           4
#
#                                     runtime_minutes  genres  directors  \
# original_title
# #1 Serial Killer                                 30      30         30
# #5                                                2       9          9
# #50Fathers                                        9       9          9
# #66                                              10      10         10
# #82 Summits                                       5       5          5
# ...                                             ...     ...        ...
# ärtico                                           50      50         50
# è solo questione di punti di vista                8       8          8
# è solo questione di tempo                        15      15         15
# élèctions piege à cons                            0       6          6
# împetu                                            0       4          4
#
#                                     writers  ordering_x  nconst  category  \
# original_title
# #1 Serial Killer                         30          30      30        30
# #5                                        9           9       9         9
# #50Fathers                                9           9       9         9
# #66                                      10          10      10        10
# #82 Summits                               0           5       5         5
# ...                                     ...         ...     ...       ...
# ärtico                                   50          50      50        50
# è solo questione di punti di vista        8           8       8         8
# è solo questione di tempo                15          15      15        15
# élèctions piege à cons                    0           6       6         6
# împetu                                    4           4       4         4
#
#                                     ...  averagerating  numvotes  title_id  \
# original_title                      ...
# #1 Serial Killer                    ...             30        30        30
# #5                                  ...              2         2         2
# #50Fathers                          ...              0         0         9
# #66                                 ...             10        10        10
# #82 Summits                         ...              0         0         0
# ...                                 ...            ...       ...       ...
# ärtico                              ...             50        50        50
# è solo questione di punti di vista  ...              0         0         8
# è solo questione di tempo           ...              0         0        15
# élèctions piege à cons              ...              0         0         0
# împetu                              ...              0         0         4
#
#                                     ordering_y  title  region  language  \
# original_title
# #1 Serial Killer                            30     30      10         0
# #5                                           2      2       2         0
# #50Fathers                                   9      9       9         0
# #66                                         10     10      10         0
# #82 Summits                                  0      0       0         0
# ...                                        ...    ...     ...       ...
# ärtico                                      50     50      40         0
# è solo questione di punti di vista           8      8       8         0
# è solo questione di tempo                   15     15      10         0
# élèctions piege à cons                       0      0       0         0
# împetu                                       4      4       4         0
#
#                                     types  attributes  is_original_title
# original_title
# #1 Serial Killer                       20           0                 30
# #5                                      0           0                  2
# #50Fathers                              0           0                  9
# #66                                     0           0                 10
# #82 Summits                             0           0                  0
# ...                                   ...         ...                ...
# ärtico                                 30           0                 50
# è solo questione di punti di vista      0           0                  8
# è solo questione di tempo              10           0                 15
# élèctions piege à cons                  0           0                  0
# împetu                                  0           0                  4
#
# [137773 rows x 22 columns]

# %%
people_info_df
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %%
fifth_join = fourth_join.merge(people_info_df, how='left', left_on='nconst', right_on='nconst')
fifth_join
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 2975780  tt9916754  Chico Albuquerque - Revelações
# 2975781  tt9916754  Chico Albuquerque - Revelações
# 2975782  tt9916754  Chico Albuquerque - Revelações
# 2975783  tt9916754  Chico Albuquerque - Revelações
# 2975784  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# 4                             Sunghursh        2013            175.0
# ...                                 ...         ...              ...
# 2975780  Chico Albuquerque - Revelações        2013              NaN
# 2975781  Chico Albuquerque - Revelações        2013              NaN
# 2975782  Chico Albuquerque - Revelações        2013              NaN
# 2975783  Chico Albuquerque - Revelações        2013              NaN
# 2975784  Chico Albuquerque - Revelações        2013              NaN
#
#                      genres            directors  \
# 0        Action,Crime,Drama            nm0712540
# 1        Action,Crime,Drama            nm0712540
# 2        Action,Crime,Drama            nm0712540
# 3        Action,Crime,Drama            nm0712540
# 4        Action,Crime,Drama            nm0712540
# ...                     ...                  ...
# 2975780         Documentary  nm9272490,nm8349149
# 2975781         Documentary  nm9272490,nm8349149
# 2975782         Documentary  nm9272490,nm8349149
# 2975783         Documentary  nm9272490,nm8349149
# 2975784         Documentary  nm9272490,nm8349149
#
#                                          writers  ordering_x      nconst  ...  \
# 0        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 1        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 2        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 3        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# 4        nm0023551,nm1194313,nm0347899,nm1391276        10.0   nm0006210  ...
# ...                                          ...         ...         ...  ...
# 2975780                      nm8349149,nm9272490         5.0   nm9272490  ...
# 2975781                      nm8349149,nm9272490         6.0   nm8349149  ...
# 2975782                      nm8349149,nm9272490         7.0   nm9272489  ...
# 2975783                      nm8349149,nm9272490         8.0  nm10538638  ...
# 2975784                      nm8349149,nm9272490         9.0  nm10538635  ...
#
#         region language     types                   attributes  \
# 0           IN       hi       NaN  alternative transliteration
# 1          NaN      NaN  original                          NaN
# 2           IN      NaN       NaN                          NaN
# 3           IN       hi       NaN  alternative transliteration
# 4           IN       hi       NaN         alternative spelling
# ...        ...      ...       ...                          ...
# 2975780    NaN      NaN       NaN                          NaN
# 2975781    NaN      NaN       NaN                          NaN
# 2975782    NaN      NaN       NaN                          NaN
# 2975783    NaN      NaN       NaN                          NaN
# 2975784    NaN      NaN       NaN                          NaN
#
#          is_original_title            primary_name  birth_year death_year  \
# 0                      0.0                 Naushad      1919.0     2006.0
# 1                      1.0                 Naushad      1919.0     2006.0
# 2                      0.0                 Naushad      1919.0     2006.0
# 3                      0.0                 Naushad      1919.0     2006.0
# 4                      0.0                 Naushad      1919.0     2006.0
# ...                    ...                     ...         ...        ...
# 2975780                NaN           Angela Gurgel         NaN        NaN
# 2975781                NaN  Vinicius Augusto Bozzo      1985.0        NaN
# 2975782                NaN           Marcelo Alves         NaN        NaN
# 2975783                NaN       Wellington Barros         NaN        NaN
# 2975784                NaN             Odério Dias         NaN        NaN
#
#                            primary_profession  \
# 0        composer,soundtrack,music_department
# 1        composer,soundtrack,music_department
# 2        composer,soundtrack,music_department
# 3        composer,soundtrack,music_department
# 4        composer,soundtrack,music_department
# ...                                       ...
# 2975780                       director,writer
# 2975781                writer,editor,director
# 2975782     cinematographer,producer,director
# 2975783                       cinematographer
# 2975784                       cinematographer
#
#                                    known_for_titles
# 0           tt0054910,tt0266765,tt0044392,tt0053999
# 1           tt0054910,tt0266765,tt0044392,tt0053999
# 2           tt0054910,tt0266765,tt0044392,tt0053999
# 3           tt0054910,tt0266765,tt0044392,tt0053999
# 4           tt0054910,tt0266765,tt0044392,tt0053999
# ...                                             ...
# 2975780   tt10006546,tt10231530,tt7378802,tt9916754
# 2975781   tt9916754,tt10118270,tt7378802,tt10163584
# 2975782  tt10011778,tt7373112,tt10056288,tt10011880
# 2975783                        tt10169058,tt9916754
# 2975784  tt9916754,tt10225704,tt10169058,tt10006546
#
# [2975785 rows x 28 columns]

# %%
fifth_join.groupby('original_title')
# Out:
#                                     tconst  primary_title  start_year  \
# original_title
# #1 Serial Killer                        30             30          30
# #5                                       9              9           9
# #50Fathers                               9              9           9
# #66                                     10             10          10
# #82 Summits                              5              5           5
# ...                                    ...            ...         ...
# ärtico                                  50             50          50
# è solo questione di punti di vista       8              8           8
# è solo questione di tempo               15             15          15
# élèctions piege à cons                   6              6           6
# împetu                                   4              4           4
#
#                                     runtime_minutes  genres  directors  \
# original_title
# #1 Serial Killer                                 30      30         30
# #5                                                2       9          9
# #50Fathers                                        9       9          9
# #66                                              10      10         10
# #82 Summits                                       5       5          5
# ...                                             ...     ...        ...
# ärtico                                           50      50         50
# è solo questione di punti di vista                8       8          8
# è solo questione di tempo                        15      15         15
# élèctions piege à cons                            0       6          6
# împetu                                            0       4          4
#
#                                     writers  ordering_x  nconst  category  \
# original_title
# #1 Serial Killer                         30          30      30        30
# #5                                        9           9       9         9
# #50Fathers                                9           9       9         9
# #66                                      10          10      10        10
# #82 Summits                               0           5       5         5
# ...                                     ...         ...     ...       ...
# ärtico                                   50          50      50        50
# è solo questione di punti di vista        8           8       8         8
# è solo questione di tempo                15          15      15        15
# élèctions piege à cons                    0           6       6         6
# împetu                                    4           4       4         4
#
#                                     ...  region  language  types  attributes  \
# original_title                      ...
# #1 Serial Killer                    ...      10         0     20           0
# #5                                  ...       2         0      0           0
# #50Fathers                          ...       9         0      0           0
# #66                                 ...      10         0      0           0
# #82 Summits                         ...       0         0      0           0
# ...                                 ...     ...       ...    ...         ...
# ärtico                              ...      40         0     30           0
# è solo questione di punti di vista  ...       8         0      0           0
# è solo questione di tempo           ...      10         0     10           0
# élèctions piege à cons              ...       0         0      0           0
# împetu                              ...       4         0      0           0
#
#                                     is_original_title  primary_name  \
# original_title
# #1 Serial Killer                                   30            30
# #5                                                  2             9
# #50Fathers                                          9             9
# #66                                                10            10
# #82 Summits                                         0             5
# ...                                               ...           ...
# ärtico                                             50            50
# è solo questione di punti di vista                  8             8
# è solo questione di tempo                          15            15
# élèctions piege à cons                              0             6
# împetu                                              4             4
#
#                                     birth_year  death_year  \
# original_title
# #1 Serial Killer                             3           0
# #5                                           0           0
# #50Fathers                                   0           0
# #66                                          0           0
# #82 Summits                                  1           1
# ...                                        ...         ...
# ärtico                                       5           0
# è solo questione di punti di vista           2           1
# è solo questione di tempo                    3           0
# élèctions piege à cons                       0           0
# împetu                                       0           0
#
#                                     primary_profession  known_for_titles
# original_title
# #1 Serial Killer                                    30                30
# #5                                                   3                 5
# #50Fathers                                           9                 9
# #66                                                 10                10
# #82 Summits                                          4                 2
# ...                                                ...               ...
# ärtico                                              50                50
# è solo questione di punti di vista                   8                 8
# è solo questione di tempo                           15                15
# élèctions piege à cons                               6                 6
# împetu                                               4                 4
#
# [137773 rows x 27 columns]

# %%
fifth_join.isna().sum()
# Out:
# tconst                      0
# primary_title               0
# original_title             32
# start_year                  0
# runtime_minutes        280635
# genres                  32591
# directors               20435
# writers                265826
# ordering_x               2812
# nconst                   2812
# category                 2812
# job                   2231222
# characters            1824758
# averagerating          519637
# numvotes               519637
# title_id               134509
# ordering_y             134509
# title                  134509
# region                 595279
# language              2596060
# types                 1423140
# attributes            2839834
# is_original_title      134534
# primary_name             3302
# birth_year            1833225
# death_year            2928068
# primary_profession      95934
# known_for_titles        49511
# dtype: int64
