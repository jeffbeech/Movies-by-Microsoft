# %% [markdown]
# # Microsoft Movie Studios
#
# **Author:** Team 5
# ***

# %% [markdown]
# ![director_shot.jpeg](attachment:director_shot.jpeg)

# %% [markdown]
# ## Overview
#
# This project analyzes the creative needs of <a href="http://www.microsoft.com">Microsoft</a>, an expansive computer software and hardware manufacturer.  Microsoft has made a strategic decision to create a new movie studio. Analysis of popular film genres and financial data from the Internet Movie Database <a href="http://www.imdb.com/interfaces/">(IMDb)</a> and Box Office Mojo <a href="http://www.boxofficemojo.com/"> (BOM)</a> clearly shows that top grossing films are centered around a few film types.  Additionaly, one studio group stands out as the creative leader in these genres.  Microsoft can use this analysis to set visioning, hiring practices, property acqusition and advertising for their initial resource allocation.

# %% [markdown]
# ## Business Problem
#
# Microsoft has decided to expand its considerable expertise into the area of producing feature films.  As a new entry into this competitive and creative arena, they need an analysis of the types of films that are doing best at the box office.  Using data from the Internet Movie Database <a href="http://www.imdb.com/interfaces/">(IMDb)</a>  and Box Office Mojo<a href="http://www.boxofficemojo.com/"> (BOM)</a>, I will describe patterns from succesful production houses. By analyzing and comparing film generes, gross receipts, year to year consistency and studio success, this analysis will aid Microsoft in clarifying the vision, culture and resource management for their new subsidiary.

# %% [markdown]
# ## Data Understanding
#
# The three data sets we are using are from the Internet Movie Database (IMDb) and a subsiderary company, Box Office Mojo (BOM).  Both are owned by Amazon, and represent the largest repository of film data available.  These files have information about movie genres, gross receipts domestically and abroad, plus basic things like titles, release year, studios, runtime, etc.

# %%
# Import relevant modules

import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('data/title.basics.csv')
df2 = pd.read_csv('data/title.ratings.csv')
df3 = pd.read_csv('data/bom.movie_gross.csv')
df4 = pd.read_csv('data/tn.movie_budgets.csv')

df1.shape, df2.shape, df3.shape, df3.shape
# Out:
# ((146144, 6), (73856, 3), (3387, 5), (3387, 5))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# ### DF1
#
# This data set contains titles, premiere year, runtime and film genres, along with an index.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
df1['start_year'].value_counts()
# Out:
# 2017    17504
# 2016    17272
# 2018    16849
# 2015    16243
# 2014    15589
# 2013    14709
# 2012    13787
# 2011    12900
# 2010    11849
# 2019     8379
# 2020      937
# 2021       83
# 2022       32
# 2023        5
# 2024        2
# 2027        1
# 2026        1
# 2025        1
# 2115        1
# Name: start_year, dtype: int64

# %%
df1['genres'].value_counts()
# Out:
# Documentary                 32185
# Drama                       21486
# Comedy                       9177
# Horror                       4372
# Comedy,Drama                 3519
#                             ...
# Animation,Horror,Sci-Fi         1
# Comedy,Crime,Western            1
# Animation,Crime,Mystery         1
# Musical,Romance,Western         1
# Biography,Mystery,Sci-Fi        1
# Name: genres, Length: 1085, dtype: int64

# %%
len(df1['tconst'].unique()) # the output matches the number of entries for 'tconst'.  The values are unique
# Out:
# 146144

# %% [markdown]
# ### DF2
#
# This data set contains fan rating and voting information along with an index.

# %%
df2.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
df2['averagerating'].value_counts(bins=10)
# Out:
# (6.4, 7.3]     19088
# (5.5, 6.4]     16563
# (7.3, 8.2]     12473
# (4.6, 5.5]      9861
# (3.7, 4.6]      5452
# (8.2, 9.1]      5354
# (2.8, 3.7]      2819
# (1.9, 2.8]      1112
# (9.1, 10.0]      715
# (0.99, 1.9]      419
# Name: averagerating, dtype: int64

# %%
df2['numvotes'].value_counts(bins=12)
# Out:
# (-1836.062, 153426.75]     73443
# (153426.75, 306848.5]        243
# (306848.5, 460270.25]         91
# (460270.25, 613692.0]         45
# (613692.0, 767113.75]         22
# (767113.75, 920535.5]          4
# (920535.5, 1073957.25]         3
# (1073957.25, 1227379.0]        2
# (1687644.25, 1841066.0]        1
# (1380800.75, 1534222.5]        1
# (1227379.0, 1380800.75]        1
# (1534222.5, 1687644.25]        0
# Name: numvotes, dtype: int64

# %%
len(df2['tconst'].unique()) # the output matches the number of entries for 'tconst'.  The values are unique
# Out:
# 73856

# %% [markdown]
# ## DF3
#
# This data set contains titles, production studio, year of release from 2010 - 2018, and domestic and foreign gross receipts.

# %%
df3.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df3['studio'].value_counts()
# Out:
# IFC             166
# Uni.            147
# WB              140
# Magn.           136
# Fox             136
#                ...
# Conglomerate      1
# UEP               1
# CFI               1
# Saban             1
# MSF               1
# Name: studio, Length: 257, dtype: int64

# %%
df3['year'].value_counts()
# Out:
# 2015    450
# 2016    436
# 2012    400
# 2011    399
# 2014    395
# 2013    350
# 2010    328
# 2017    321
# 2018    308
# Name: year, dtype: int64

# %%
# Updating column names for readability in graphs
df3['studio'].replace({"WB (NL)": "WB"}, inplace=True)
df3['studio'].replace({"WB": "Warner Bros", 'BV': 'Disney', 'Uni.': "Universal", 'P/DW': 'DreamWorks', 'Par.': 'Paramount'}, inplace=True)
df3['studio'].value_counts()
# Out:
# Warner Bros    185
# IFC            166
# Universal      147
# Magn.          136
# Fox            136
#               ...
# PI               1
# UHE              1
# E1               1
# Blue Fox         1
# MSF              1
# Name: studio, Length: 256, dtype: int64

# %% [markdown]
# ## My initial process:
#
# In the initial view of the three data files, a few things stood out.
# 1.  All three files had low number of null values.
# 2.  The two files from IMDB had an index that appeared to be common between the them.
# 3.  The file containing the gross receipts info had considerably less rows than the other two.  This file
#     is going to strongly influence the size of the merged data set.

# %% [markdown]
# ## Data Preparation
#
# Each dataset contains pieces of information vital to making an analysis.  My process is:
#
#     Doing an inner merge on df1 and df2 by 'tconst' to create the dataset df_imbd
#     Doing an inner merge on df_imbd and df3 by 'title' to create a complete dataset.
#     Cleaning up the data:
#         1.  Delete the 'original_title', 'start_year' and the 'runtime_minutes" columns
#         2.  Change the foreign_gross column to float64 Dtype from object Dtype
#         3.  Add a column that is the sum of 'domestic_gross' and 'foreign_gross' entitled 'worldwide_gross'
#         4.  Delete duplicates in the title column

# %% [markdown]
# ### Merging datasets

# %% [markdown]
# This will merge df1 and df2 by their common index numbers, and will drop the 'tconst' rows that are not common between the two datasets.

# %%
df_imdb = df1.merge(df2, on="tconst", how = 'left')
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
#  6   averagerating    73856 non-null   float64
#  7   numvotes         73856 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 10.0+ MB

# %%
df_imdb['primary_title'].isin(df3['title']).value_counts()
# Out:
# False    142780
# True       3364
# Name: primary_title, dtype: int64

# %% [markdown]
# First, we'll rename the 'primary_title' column in 'df_imdb' to 'title'

# %%
df_imdb.rename(columns={'primary_title': 'title'}, inplace=True)

# %% [markdown]
# Now we'll prepare the the df3 and df4 files for merging, which contains financial and studio data.

# %%
df_bom = df3.drop(['domestic_gross','foreign_gross'], axis = 1)

# %%
df4.rename(columns={'movie': 'title'}, inplace=True)
df4
# Out:
#       id  release_date                                        title  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   title              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df_money = df_bom.merge(df4, on = 'title', how = 'right')
df_money
# Out:
#                                             title  studio    year  id  \
# 0                                          Avatar     NaN     NaN   1
# 1     Pirates of the Caribbean: On Stranger Tides  Disney  2011.0   2
# 2                                    Dark Phoenix     NaN     NaN   3
# 3                         Avengers: Age of Ultron  Disney  2015.0   4
# 4               Star Wars Ep. VIII: The Last Jedi     NaN     NaN   5
# ...                                           ...     ...     ...  ..
# 5777                                       Red 11     NaN     NaN  78
# 5778                                    Following     NaN     NaN  79
# 5779                Return to the Land of Wonders     NaN     NaN  80
# 5780                         A Plague So Pleasant     NaN     NaN  81
# 5781                            My Date With Drew     NaN     NaN  82
#
#       release_date production_budget domestic_gross worldwide_gross
# 0     Dec 18, 2009      $425,000,000   $760,507,625  $2,776,345,279
# 1     May 20, 2011      $410,600,000   $241,063,875  $1,045,663,875
# 2      Jun 7, 2019      $350,000,000    $42,762,350    $149,762,350
# 3      May 1, 2015      $330,600,000   $459,005,868  $1,403,013,963
# 4     Dec 15, 2017      $317,000,000   $620,181,382  $1,316,721,747
# ...            ...               ...            ...             ...
# 5777  Dec 31, 2018            $7,000             $0              $0
# 5778   Apr 2, 1999            $6,000        $48,482        $240,495
# 5779  Jul 13, 2005            $5,000         $1,338          $1,338
# 5780  Sep 29, 2015            $1,400             $0              $0
# 5781   Aug 5, 2005            $1,100       $181,041        $181,041
#
# [5782 rows x 8 columns]

# %% [markdown]
# This merge did not completely give the results we wanted, but was the best of the options available.  It resulted in having to hard code some data to complete our top grossing movies list.
#
# Now we'll merge the IMBd data with the BOM data, which has all the gross receipts details.  The commonality between these files is the titles; of the 3387 rows in the BOM data file, 3025 of them have matching data in the 'title' column with the 'primary_title' column in the IMDb file.

# %%
df_all3 = df_imdb.merge(df_money, on="title", how = 'right')

# %%
df_all3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 0 to 7220
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             3815 non-null   object
#  1   title              7221 non-null   object
#  2   original_title     3814 non-null   object
#  3   start_year         3815 non-null   float64
#  4   runtime_minutes    3328 non-null   float64
#  5   genres             3743 non-null   object
#  6   averagerating      2875 non-null   float64
#  7   numvotes           2875 non-null   float64
#  8   studio             1681 non-null   object
#  9   year               1682 non-null   float64
#  10  id                 7221 non-null   int64
#  11  release_date       7221 non-null   object
#  12  production_budget  7221 non-null   object
#  13  domestic_gross     7221 non-null   object
#  14  worldwide_gross    7221 non-null   object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 902.6+ KB

# %% [markdown]
# ### Data Cleaning

# %%
# remove all but numbers in  the gross earnings columns
df_all3['domestic_gross'] = df_all3['domestic_gross'].apply(str).str.replace(r"[a-zA-Z$,]",'')
df_all3['worldwide_gross'] = df_all3['worldwide_gross'].apply(str).str.replace(r"[a-zA-Z$,]",'')

# %%
# convert gross earnings columns to numeric
df_all3['domestic_gross'] = pd.to_numeric(df_all3['domestic_gross'], errors = 'coerce')
df_all3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 0 to 7220
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             3815 non-null   object
#  1   title              7221 non-null   object
#  2   original_title     3814 non-null   object
#  3   start_year         3815 non-null   float64
#  4   runtime_minutes    3328 non-null   float64
#  5   genres             3743 non-null   object
#  6   averagerating      2875 non-null   float64
#  7   numvotes           2875 non-null   float64
#  8   studio             1681 non-null   object
#  9   year               1682 non-null   float64
#  10  id                 7221 non-null   int64
#  11  release_date       7221 non-null   object
#  12  production_budget  7221 non-null   object
#  13  domestic_gross     7221 non-null   int64
#  14  worldwide_gross    7221 non-null   object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 902.6+ KB

# %%
df_all3['worldwide_gross'] = pd.to_numeric(df_all3['worldwide_gross'], errors = 'coerce')

# %%
df_all3 = df_all3.drop_duplicates(subset=['title'])

# %%
# df_all3['foreign_gross'] = df_all3['foreign_gross'].fillna(0)

# df_all3.insert(loc = 8,
#          column = 'worldwide_gross',
#          value = 0) # insert column 'worldwide_gross'
# df_all3['worldwide_gross'] = df_all3.apply(lambda row: row['domestic_gross'] + row['foreign_gross'], axis=1)

# %%
df_all3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5698 entries, 0 to 7220
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             2312 non-null   object
#  1   title              5698 non-null   object
#  2   original_title     2312 non-null   object
#  3   start_year         2312 non-null   float64
#  4   runtime_minutes    2138 non-null   float64
#  5   genres             2287 non-null   object
#  6   averagerating      2033 non-null   float64
#  7   numvotes           2033 non-null   float64
#  8   studio             1237 non-null   object
#  9   year               1238 non-null   float64
#  10  id                 5698 non-null   int64
#  11  release_date       5698 non-null   object
#  12  production_budget  5698 non-null   object
#  13  domestic_gross     5698 non-null   int64
#  14  worldwide_gross    5698 non-null   int64
# dtypes: float64(5), int64(3), object(7)
# memory usage: 712.2+ KB

# %%
# Save cleaned dataset as CSV
df_all3.to_csv('./data/df_all3.csv')

# %%
# pd.set_option("display.max_rows", None)
df_horror = df_all3.dropna(subset = ['genres'])
df_horror['domestic_gross'] = df_horror['domestic_gross'].apply(str).str.replace(r"[a-zA-Z$,]",'')
df_horror['worldwide_gross'] = df_horror['worldwide_gross'].apply(str).str.replace(r"[a-zA-Z$,]",'')
df_horror['production_budget'] = df_horror['production_budget'].apply(str).str.replace(r"[a-zA-Z$,]",'')
df_horror['worldwide_gross'] = pd.to_numeric(df_horror['worldwide_gross'], errors = 'coerce')
df_horror['production_budget'] = pd.to_numeric(df_horror['production_budget'], errors = 'coerce')
df_horror = df_horror.loc[df_horror['genres'].str.contains('Horror')]
df_horror['profit'] = df_horror['worldwide_gross'] - df_horror['production_budget']
df_horror['ROI'] = df_horror['profit'] / df_horror['production_budget'] * 100
df_horror
# Out:
# <ipython-input-73-34d7229f9205>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_horror['domestic_gross'] = df_horror['domestic_gross'].apply(str).str.replace(r"[a-zA-Z$,]",'')
# <ipython-input-73-34d7229f9205>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_horror['worldwide_gross'] = df_horror['worldwide_gross'].apply(str).str.replace(r"[a-zA-Z$,]",'')
# <ipython-input-73-34d7229f9205>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_horror['production_budget'] = df_horror['production_budget'].apply(str).str.replace(r"[a-zA-Z$,]",'')
# <ipython-input-73-34d7229f9205>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_horror['worldwide_gross'] = pd.to_numeric(df_horror['worldwide_gross'], errors = 'coerce')
# <ipython-input-73-34d7229f9205>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_horror['production_budget'] = pd.to_numeric(df_horror['production_budget'], errors = 'coerce')
#           tconst                                     title  \
# 0      tt1775309                                    Avatar
# 87     tt0816711                               World War Z
# 118    tt4779682                                   The Meg
# 236    tt1077368                              Dark Shadows
# 238    tt0780653                               The Wolfman
# 576    tt2316204                           Alien: Covenant
# 736    tt1596723                                     Click
# 780    tt5354458                         Conspiracy Theory
# 802    tt1254978                                  Daylight
# 809    tt2179165                                      Nine
# 995   tt10343876                                      Next
# 1018   tt1611224           Abraham Lincoln: Vampire Hunter
# 1067   tt1855325                Resident Evil: Retribution
# 1081   tt1418377                           I, Frankenstein
# 1210   tt1538403     The Mortal Instruments: City of Bones
# 1248   tt7981492                                   Sabrina
# 1257   tt1220634                  Resident Evil: Afterlife
# 1294   tt6840314                            City of Angels
# 1318   tt1298649                                 The Watch
# 1328   tt2798920                              Annihilation
# 1329   tt2554274                              Crimson Peak
# 1436   tt2145909                             The Forgotten
# 1443   tt1428538            Hansel & Gretel: Witch Hunters
# 1456  tt10073018                                  The Game
# 1549  tt10339624                                   The One
# 1678   tt2837194                                   Rebound
# 1740   tt1486185                           Red Riding Hood
# 1852   tt1622979                       Final Destination 5
# 1860   tt1262416                                  Scream 4
# 1892   tt2592614          Resident Evil: The Final Chapter
# 1901   tt4203258                               The Reaping
# 1945   tt1976009                       Victor Frankenstein
# 2013   tt0905372                                 The Thing
# 2028   tt6413518                               The Express
# 2032   tt1632705                                     Creed
# 2045   tt1161864                                  The Rite
# 2071   tt1396484                                        It
# 2086   tt5097012                                        21
# 2096   tt1179056                 A Nightmare on Elm Street
# 2110   tt1029360                               Poltergeist
# 2246   tt1093357                          The Darkest Hour
# 2276   tt1817771                          Freaks of Nature
# 2381   tt1588173                               Warm Bodies
# 2428   tt1259521                    The Cabin in the Woods
# 2439   tt1728973                                The Family
# 2449   tt1939659                                    Carrie
# 2459   tt2377322                      Deliver Us from Evil
# 2483   tt1438176                              Fright Night
# 2634   tt1374989           Pride and Prejudice and Zombies
# 2691   tt2039338                                Flatliners
# 2694   tt4828330                                   Red Eye
# 2701   tt1038686                                    Legion
# 2794   tt3155654                             Hide and Seek
# 2853   tt0498381                                     Rings
# 2858   tt1270761               Don't Be Afraid of the Dark
# 2869   tt1633356                            Shark Night 3D
# 2882   tt2577542                                    Legend
# 2897   tt0872230                           My Soul to Take
# 3001   tt0464154                                Piranha 3D
# 3113   tt1726592                      Before I Go to Sleep
# 3127   tt0837563                              Pet Sematary
# 3155   tt7043012                            Velvet Buzzsaw
# 3167   tt1457767                             The Conjuring
# 3241   tt1572315                         Texas Chainsaw 3D
# 3281   tt1500906                                  Vampires
# 3329   tt1228987                                 Let Me In
# 3374   tt1034415                                  Suspiria
# 3405   tt3319920                                Regression
# 3419   tt2737304                                  Bird Box
# 3438   tt0455407                               The Crazies
# 3469   tt2243377                               Left Behind
# 3494   tt3862750                           The Perfect Guy
# 3525   tt2122313                                The Circle
# 3610   tt1403241                                    Wolves
# 3625   tt1748179                                Red Lights
# 3648   tt1288558                                 Evil Dead
# 3675   tt1433822                            The Apparition
# 3709   tt3233610                                 Road Trip
# 3716  tt10423074                                The Unborn
# 3755   tt1111235                                    Trance
# 3772   tt1545106                                     Vamps
# 3796   tt5140878                       Annabelle: Creation
# 3814   tt1502407                                 Halloween
# 3819   tt1596365                        The Woman in Black
# 3831   tt3850590                                   Krampus
# 3913   tt2042684                                  The Muse
# 3956   tt1727776     Scouts Guide to the Zombie Apocalypse
# 3962   tt2364897                  The Disappointments Room
# 4047   tt0431021                            The Possession
# 4050   tt5844050                              Urban Legend
# 4123   tt1441395                            Under the Skin
# 4130   tt6133466                           The First Purge
# 4135   tt4052882                              The Shallows
# 4189   tt1524575                         The Vatican Tapes
# 4196   tt0954947                      The Killer Inside Me
# 4199   tt1911644                                  The Call
# 4315   tt5322012                                 Wish Upon
# 4346   tt6243140                                  Ravenous
# 4456   tt1709143                     The Last Days on Mars
# 4476   tt4094724                  The Purge: Election Year
# 4480   tt5726086                   Insidious: The Last Key
# 4491   tt7784604                                Hereditary
# 4496   tt3348730                                    Jigsaw
# 4502   tt2443822                                   The Boy
# 4506   tt1314655                                     Devil
# 4516   tt5690360                               Slender Man
# 4522   tt1389139                     When the Bough Breaks
# 4529   tt2752772                                Sinister 2
# 4530   tt1488602                                The Forest
# 4544   tt1540011                               Blair Witch
# 4551   tt2473510  Paranormal Activity: The Ghost Dimension
# 4625   tt1748227                            The Collection
# 4717   tt1320291                                  The Reef
# 4723   tt1691450                                   Plastic
# 4732   tt0990363                                 Detention
# 4738   tt1913166                                  Nurse 3D
# 4755   tt1612319                                   Re-Kill
# 4774   tt2975578                        The Purge: Anarchy
# 4776   tt2529924                             The Strangers
# 4781   tt4361050                     Ouija: Origin of Evil
# 4783   tt8663516                              Child's Play
# 4784   tt8155288                        Happy Death Day 2U
# 4895   tt1773741                              The Intruder
# 5010   tt1974419                            The Neon Demon
# 5021   tt4030600                           The Bye Bye Man
# 5069   tt2752758                               Devil's Due
# 5082   tt1327709                                     Cyrus
# 5123   tt1756851                                     Twixt
# 5130   tt1582507            House at the End of the Street
# 5141   tt3322940                                 Annabelle
# 5204   tt4504044                               The Prodigy
# 5205   tt5734576            The Possession of Hannah Grace
# 5227   tt9087212                              Little Voice
# 5255   tt2582426                                     Julia
# 5296   tt1999890                                 Hell Fest
# 5328   tt1525366                                  Grabbers
# 5340   tt5052448                                   Get Out
# 5347   tt1778304                     Paranormal Activity 3
# 5350   tt1179933                       10 Cloverfield Lane
# 5361   tt5308322                           Happy Death Day
# 5362   tt2109184                     Paranormal Activity 4
# 5363   tt1204977                                     Ouija
# 5379   tt2473682      Paranormal Activity: The Marked Ones
# 5382   tt2388715                                    Oculus
# 5387   tt2918436                        The Lazarus Effect
# 5390   tt1285009              The Strangers: Prey at Night
# 5399   tt1331294                               The Apostle
# 5411   tt1772240                                 Apollo 18
# 5426   tt4695012                         It Comes at Night
# 5443   tt1082807                      The Belko Experiment
# 5452   tt5124556                              The Forsaken
# 5463   tt3216348                                 Incarnate
# 5470   tt4062536                                Green Room
# 5512   tt1555814                                     Grace
# 5515   tt1519461                                   Area 51
# 5518   tt1977941                               The Cottage
# 5540   tt1373405                             The Awakening
# 5550   tt1675192                              Take Shelter
# 5594   tt1881002                                    Maggie
# 5603   tt2081194                 Hansel & Gretel Get Baked
# 5625   tt3393372                  Night of the Living Dead
# 5642   tt3181822                         The Boy Next Door
# 5655   tt2034139                 The Last Exorcism Part II
# 5660   tt1691149                              Saving Grace
# 5663   tt1878841                              The Darkness
# 5693   tt0873886                                 Red State
# 5726   tt1464580                                Stake Land
# 5731   tt2059171                                   13 Sins
# 5773   tt2125681                             Truth or Dare
# 5781   tt4263482                                 The Witch
# 5785   tt2387433                                Dark Skies
# 5863   tt4282670                                     Feast
# 5866   tt2099556                                 Antiviral
# 5868   tt1536044                     Paranormal Activity 2
# 5870   tt2184339                                 The Purge
# 5872   tt1922777                                  Sinister
# 5909   tt1498568                                 Red River
# 5953   tt3099498                                      Tusk
# 5967   tt1640459                       Hobo with a Shotgun
# 5972   tt1686018                                  Creature
# 5989   tt1535616                                The Divide
# 5994   tt1841642                                   Demonic
# 6006   tt1327601                          Something Wicked
# 6013   tt2693114                                  Amnesiac
# 6015   tt3551400                                 Unnatural
# 6037   tt4080386                                Sardaar Ji
# 6040   tt3021984                                     Diane
# 6060   tt7064690                              Halloween II
# 6101   tt2040578                            Alien Uprising
# 6106   tt3333870                                 Antibirth
# 6155   tt1622991                                  Infected
# 6164   tt1433183                                   Sleeper
# 6168   tt3235888                                It Follows
# 6171   tt1767382                              Silent House
# 6218   tt2321549                              The Babadook
# 6250   tt1129412                                    Circle
# 6261   tt1703199                          Grave Encounters
# 6262   tt2494362                             Bone Tomahawk
# 6264   tt1623771                                  Stitches
# 6270   tt0959329                                 Nine Dead
# 6291   tt3499458                      The Walking Deceased
# 6293   tt1772261                The Curse of Downers Grove
# 6294   tt1236254                              Wind Walkers
# 6324   tt1320244                         The Last Exorcism
# 6348   tt1242432                      I Spit on Your Grave
# 6349   tt2100573   Living Dark: The Story of Ted the Caver
# 6360   tt4638148                                     Braid
# 6368   tt2872724                           Out of the Dark
# 6375   tt1591095                                 Insidious
# 6378   tt3832096                               Cabin Fever
# 6383   tt7153766                                    Unsane
# 6387   tt2132405                                Spellbound
# 6398   tt1731697                        The Lords of Salem
# 6399   tt3835080                                        31
# 6401   tt3139764                                 Unsullied
# 6420   tt3504048                                Housebound
# 6430   tt3526286                                   #Horror
# 6445   tt1480658          Eddie: The Sleepwalking Cannibal
# 6448   tt0464054             House at the End of the Drive
# 6480  tt10430534                                   Rebecca
# 6488   tt3669462                                     Bodom
# 6512   tt4847546                               Blood Feast
# 6519   tt2180333                                 Crowsnest
# 6520   tt1827354                                  Airborne
# 6522   tt2622294                           Bleeding Hearts
# 6523   tt1943014                         The Wicked Within
# 6534   tt1534085                  Beyond the Black Rainbow
# 6544   tt0923653                           The Dead Undead
# 6545   tt3043194                     The Vatican Exorcisms
# 6550   tt1560985                          The Devil Inside
# 6552   tt3713166                                Unfriended
# 6555   tt1853739                               You're Next
# 6556   tt1991245                         Chernobyl Diaries
# 6557   tt5694044                               The Howling
# 6567   tt4761916                      Unfriended: Dark Web
# 6569   tt2403021                         The Green Inferno
# 6619   tt2400463                            The Invitation
# 6660   tt2149137               Snow White: A Deadly Summer
# 6661   tt1838722                              Truth or Die
# 6662   tt1930294                                Black Rock
# 6665   tt2446502                             Zombie Hunter
# 6668   tt2165765                               Fear Clinic
# 6683   tt2011276                           Banshee Chapter
# 6692   tt4191580                           Meet the Blacks
# 6723   tt1788391                                 Kill List
# 6724   tt1916755                                    Vessel
# 6734   tt1594562                            The Innkeepers
# 6737   tt8352082                                    Undead
# 6765   tt2187884                      Escape from Tomorrow
# 6801   tt5268278                              Love Letters
# 6838   tt1612774                                    Rubber
# 6867   tt1884318                           Girls Gone Dead
# 6871   tt1764615                              Subconscious
# 6873   tt1958007                                  Roadside
# 6875   tt2403415              Love in the Time of Monsters
# 6879   tt1986015                               Going Under
# 6881   tt3892618            Alleluia! The Devil's Carnival
# 6914   tt5569344                                 Tarnation
# 6936   tt2069843                                    Maniac
# 6974   tt1991199                           Teeth and Blood
# 6996   tt9125468                                Sugar Town
# 7018   tt1342096                                 Butterfly
# 7065   tt2049518              Sanctuary; Quite a Conundrum
# 7090   tt2503358                             Speak No Evil
# 7104   tt2309260                               The Gallows
# 7129   tt2797642                         The Night Visitor
# 7137   tt1610996                                  Absentia
# 7145   tt1861343                                   Hayride
# 7156   tt2442662                            Run, Hide, Die
# 7163   tt1716760                            Raymond Did It
# 7166   tt2469216         Her Cry: La Llorona Investigation
# 7173   tt3123250                                Paraphobia
# 7182   tt1945044                                    Exeter
# 7196   tt1781935                                The Ridges
# 7204   tt6619196                                     Clean
# 7216   tt7837402                                    Red 11
# 7219   tt2107644                      A Plague So Pleasant
#
#                                 original_title  start_year  runtime_minutes  \
# 0                                        Abatâ      2011.0             93.0
# 87                                 World War Z      2013.0            116.0
# 118                                    The Meg      2018.0            113.0
# 236                               Dark Shadows      2012.0            113.0
# 238                                The Wolfman      2010.0            103.0
# 576                            Alien: Covenant      2017.0            122.0
# 736                                      Click      2010.0            127.0
# 780                               Lake on Fire      2016.0             79.0
# 802                                   Daylight      2010.0             75.0
# 809                                       Nine      2016.0              NaN
# 995                                       Next      2019.0              7.0
# 1018           Abraham Lincoln: Vampire Hunter      2012.0            105.0
# 1067                Resident Evil: Retribution      2012.0             95.0
# 1081                           I, Frankenstein      2014.0             92.0
# 1210     The Mortal Instruments: City of Bones      2013.0            130.0
# 1248                                   Sabrina      2018.0            113.0
# 1257                  Resident Evil: Afterlife      2010.0             96.0
# 1294                            City of Angels      2017.0              NaN
# 1318                                 The Watch      2012.0            102.0
# 1328                              Annihilation      2018.0            115.0
# 1329                              Crimson Peak      2015.0            119.0
# 1436                             The Forgotten      2014.0             89.0
# 1443            Hansel & Gretel: Witch Hunters      2013.0             88.0
# 1456                                  The Game      2019.0              NaN
# 1549                                   The One      2020.0              NaN
# 1678                                   Rebound      2014.0             84.0
# 1740                           Red Riding Hood      2011.0            100.0
# 1852                       Final Destination 5      2011.0             92.0
# 1860                                  Scream 4      2011.0            111.0
# 1892          Resident Evil: The Final Chapter      2016.0            107.0
# 1901                                La cosecha      2014.0             84.0
# 1945                       Victor Frankenstein      2015.0            110.0
# 2013                                 The Thing      2011.0            103.0
# 2028                               The Express      2017.0             90.0
# 2032                                     Creed      2010.0             77.0
# 2045                                  The Rite      2011.0            114.0
# 2071                                        It      2017.0            135.0
# 2086                                        21      2016.0             98.0
# 2096                 A Nightmare on Elm Street      2010.0             95.0
# 2110                               Poltergeist      2015.0             93.0
# 2246                          The Darkest Hour      2011.0             89.0
# 2276                          Freaks of Nature      2015.0             92.0
# 2381                               Warm Bodies      2013.0             98.0
# 2428                    The Cabin in the Woods      2011.0             95.0
# 2439                                The Family      2011.0             88.0
# 2449                                    Carrie      2013.0            100.0
# 2459                      Deliver Us from Evil      2014.0            118.0
# 2483                              Fright Night      2011.0            106.0
# 2634           Pride and Prejudice and Zombies      2016.0            108.0
# 2691                                Flatliners      2017.0            109.0
# 2694                                   Red Eye      2017.0             73.0
# 2701                                    Legion      2010.0            100.0
# 2794                           Sum-bakk-og-jil      2013.0            107.0
# 2853                                     Rings      2017.0            102.0
# 2858               Don't Be Afraid of the Dark      2010.0             99.0
# 2869                            Shark Night 3D      2011.0             90.0
# 2882                                    Legend      2013.0            134.0
# 2897                           My Soul to Take      2010.0            107.0
# 3001                                Piranha 3D      2010.0             88.0
# 3113                      Before I Go to Sleep      2014.0             92.0
# 3127                              Pet Sematary      2019.0            101.0
# 3155                            Velvet Buzzsaw      2019.0            113.0
# 3167                             The Conjuring      2013.0            112.0
# 3241                         Texas Chainsaw 3D      2013.0             92.0
# 3281                                  Vampires      2010.0             88.0
# 3329                                 Let Me In      2010.0            116.0
# 3374                                  Suspiria      2018.0            152.0
# 3405                                Regression      2015.0            106.0
# 3419                                  Bird Box      2018.0            124.0
# 3438                               The Crazies      2010.0            101.0
# 3469                               Left Behind      2012.0             86.0
# 3494                           The Perfect Guy      2015.0            100.0
# 3525                                   Cirkeln      2015.0            144.0
# 3610                                    Wolves      2014.0             91.0
# 3625                                Red Lights      2012.0            114.0
# 3648                                 Evil Dead      2013.0             91.0
# 3675                            The Apparition      2012.0             83.0
# 3709                                 Road Trip      2013.0             90.0
# 3716                                The Unborn      2019.0              NaN
# 3755                                    Trance      2010.0             83.0
# 3772                                     Vamps      2012.0             92.0
# 3796                       Annabelle: Creation      2017.0            109.0
# 3814                                 Halloween      2018.0            106.0
# 3819                        The Woman in Black      2012.0             95.0
# 3831                                   Krampus      2015.0             98.0
# 3913                                  The Muse      2011.0             58.0
# 3956     Scouts Guide to the Zombie Apocalypse      2015.0             93.0
# 3962                  The Disappointments Room      2016.0             85.0
# 4047                            The Possession      2012.0             92.0
# 4050                              Urban Legend      2016.0              NaN
# 4123                            Under the Skin      2013.0            108.0
# 4130                           The First Purge      2018.0             98.0
# 4135                              The Shallows      2016.0             86.0
# 4189                         The Vatican Tapes      2015.0             91.0
# 4196                      The Killer Inside Me      2010.0            109.0
# 4199                                  The Call      2013.0             94.0
# 4315                                 Wish Upon      2017.0             90.0
# 4346                               Les affamés      2017.0            104.0
# 4456                     The Last Days on Mars      2013.0             98.0
# 4476                  The Purge: Election Year      2016.0            108.0
# 4480                   Insidious: The Last Key      2018.0            103.0
# 4491                                Hereditary      2018.0            127.0
# 4496                                    Jigsaw      2017.0             92.0
# 4502                                   The Boy      2015.0            105.0
# 4506                                     Devil      2010.0             80.0
# 4516                               Slender Man      2018.0             93.0
# 4522                     When the Bough Breaks      2016.0            107.0
# 4529                                Sinister 2      2015.0             97.0
# 4530                                The Forest      2011.0             98.0
# 4544                               Blair Witch      2016.0             89.0
# 4551  Paranormal Activity: The Ghost Dimension      2015.0             88.0
# 4625                            The Collection      2012.0             82.0
# 4717                                  The Reef      2010.0             94.0
# 4723                                   Plastic      2011.0             80.0
# 4732                                 Detention      2010.0             81.0
# 4738                                 Nurse 3-D      2013.0             84.0
# 4755                                   Re-Kill      2015.0             88.0
# 4774                        The Purge: Anarchy      2014.0            103.0
# 4776                             The Strangers      2012.0              NaN
# 4781                     Ouija: Origin of Evil      2016.0             99.0
# 4783                              Child's Play      2019.0            120.0
# 4784                        Happy Death Day 2U      2019.0            100.0
# 4895                             Khew ar-khard      2010.0            106.0
# 5010                            The Neon Demon      2016.0            117.0
# 5021                           The Bye Bye Man      2017.0             96.0
# 5069                               Devil's Due      2014.0             89.0
# 5082                                     Cyrus      2010.0             87.0
# 5123                                     Twixt      2011.0             88.0
# 5130            House at the End of the Street      2012.0            101.0
# 5141                                 Annabelle      2014.0             99.0
# 5204                               The Prodigy      2019.0             92.0
# 5205            The Possession of Hannah Grace      2018.0             86.0
# 5227                              Little Voice      2018.0              NaN
# 5255                                     Julia      2014.0             95.0
# 5296                                 Hell Fest      2018.0             89.0
# 5328                                  Grabbers      2012.0             94.0
# 5340                                   Get Out      2017.0            104.0
# 5347                     Paranormal Activity 3      2011.0             83.0
# 5350                       10 Cloverfield Lane      2016.0            103.0
# 5361                           Happy Death Day      2017.0             96.0
# 5362                     Paranormal Activity 4      2012.0             88.0
# 5363                                     Ouija      2014.0             89.0
# 5379      Paranormal Activity: The Marked Ones      2014.0             84.0
# 5382                                    Oculus      2013.0            104.0
# 5387                        The Lazarus Effect      2015.0             83.0
# 5390              The Strangers: Prey at Night      2018.0             85.0
# 5399                                O Apóstolo      2012.0             80.0
# 5411                                 Apollo 18      2011.0             86.0
# 5426                         It Comes at Night      2017.0             91.0
# 5443                      The Belko Experiment      2016.0             89.0
# 5452                              The Forsaken      2015.0             86.0
# 5463                                 Incarnate      2016.0             91.0
# 5470                                Green Room      2015.0             95.0
# 5512                                     Grace      2011.0             98.0
# 5515                                   Area 51      2015.0             91.0
# 5518                               The Cottage      2012.0             88.0
# 5540                             The Awakening      2010.0             83.0
# 5550                              Take Shelter      2011.0            121.0
# 5594                                    Maggie      2015.0             95.0
# 5603                 Hansel & Gretel Get Baked      2013.0             86.0
# 5625                  Night of the Living Dead      2014.0             79.0
# 5642                         The Boy Next Door      2015.0             91.0
# 5655                 The Last Exorcism Part II      2013.0             88.0
# 5660                              Saving Grace      2010.0             85.0
# 5663                              The Darkness      2016.0             92.0
# 5693                                 Red State      2011.0             88.0
# 5726                                Stake Land      2010.0             98.0
# 5731                                   13 Sins      2014.0             93.0
# 5773                             Truth or Dare      2013.0             85.0
# 5781        The VVitch: A New-England Folktale      2015.0             92.0
# 5785                                Dark Skies      2013.0             97.0
# 5863                                     Feast      2014.0              NaN
# 5866                                 Antiviral      2012.0            108.0
# 5868                     Paranormal Activity 2      2010.0             91.0
# 5870                                 The Purge      2013.0             85.0
# 5872                                  Sinister      2012.0            110.0
# 5909                                 Red River      2011.0             77.0
# 5953                                      Tusk      2014.0            102.0
# 5967                       Hobo with a Shotgun      2011.0             86.0
# 5972                                  Creature      2011.0             93.0
# 5989                                The Divide      2011.0            112.0
# 5994                                   Demonic      2015.0             83.0
# 6006                          Something Wicked      2014.0             95.0
# 6013                                  Amnesiac      2013.0             90.0
# 6015                                 Unnatural      2015.0             89.0
# 6037                                Sardaar Ji      2015.0            141.0
# 6040                                     Diane      2017.0             82.0
# 6060                              Halloween II      2010.0              NaN
# 6101                                    U.F.O.      2012.0            101.0
# 6106                                 Antibirth      2016.0             94.0
# 6155                                  Infected      2013.0             95.0
# 6164                                   Sleeper      2012.0             86.0
# 6168                                It Follows      2014.0            100.0
# 6171                              Silent House      2011.0             86.0
# 6218                              The Babadook      2014.0             94.0
# 6250                                    Circle      2010.0             88.0
# 6261                          Grave Encounters      2011.0             92.0
# 6262                             Bone Tomahawk      2015.0            132.0
# 6264                                  Stitches      2010.0             71.0
# 6270                                 Nine Dead      2010.0             98.0
# 6291                     Walking with the Dead      2015.0             88.0
# 6293                The Curse of Downers Grove      2015.0             89.0
# 6294                              Wind Walkers      2015.0             93.0
# 6324                         The Last Exorcism      2010.0             87.0
# 6348                      I Spit on Your Grave      2010.0            108.0
# 6349   Living Dark: The Story of Ted the Caver      2013.0            112.0
# 6360                                     Braid      2018.0             82.0
# 6368                           Out of the Dark      2014.0             92.0
# 6375                                 Insidious      2010.0            103.0
# 6378                               Cabin Fever      2016.0             99.0
# 6383                                    Unsane      2018.0             98.0
# 6387                        O-ssak-han yeon-ae      2011.0            114.0
# 6398                        The Lords of Salem      2012.0            101.0
# 6399                                        31      2016.0            102.0
# 6401                                 Unsullied      2014.0             93.0
# 6420                                Housebound      2014.0            107.0
# 6430                                   #Horror      2015.0            101.0
# 6445                                     Eddie      2012.0             90.0
# 6448             House at the End of the Drive      2014.0             91.0
# 6480                                   Rebecca      2018.0              NaN
# 6488                                     Bodom      2014.0             65.0
# 6512                               Blood Feast      2016.0             90.0
# 6519                                 Crowsnest      2012.0             84.0
# 6520                                  Airborne      2012.0             81.0
# 6522                           Bleeding Hearts      2015.0            100.0
# 6523                         The Wicked Within      2015.0             84.0
# 6534                  Beyond the Black Rainbow      2010.0            110.0
# 6544                           The Dead Undead      2010.0             89.0
# 6545                     The Vatican Exorcisms      2013.0             76.0
# 6550                          The Devil Inside      2012.0             83.0
# 6552                                Unfriended      2014.0             83.0
# 6555                               You're Next      2011.0             95.0
# 6556                         Chernobyl Diaries      2012.0             86.0
# 6557                               The Howling      2017.0             83.0
# 6567                      Unfriended: Dark Web      2018.0             92.0
# 6569                         The Green Inferno      2013.0            100.0
# 6619                            The Invitation      2015.0            100.0
# 6660               Snow White: A Deadly Summer      2012.0             83.0
# 6661                             Truth or Dare      2012.0             96.0
# 6662                                Black Rock      2012.0             83.0
# 6665                             Zombie Hunter      2013.0             93.0
# 6668                               Fear Clinic      2014.0             95.0
# 6683                           Banshee Chapter      2013.0             87.0
# 6692                           Meet the Blacks      2016.0             94.0
# 6723                                 Kill List      2011.0             95.0
# 6724                                    Vessel      2011.0              NaN
# 6734                            The Innkeepers      2011.0            101.0
# 6737                                    Undead      2018.0              NaN
# 6765                      Escape from Tomorrow      2013.0             90.0
# 6801                              Love Letters      2015.0            134.0
# 6838                                    Rubber      2010.0             82.0
# 6867                           Girls Gone Dead      2012.0            104.0
# 6871                              Subconscious      2010.0             72.0
# 6873                                  Roadside      2013.0             90.0
# 6875              Love in the Time of Monsters      2014.0             97.0
# 6879                               Going Under      2011.0             83.0
# 6881            Alleluia! The Devil's Carnival      2016.0             97.0
# 6914                                 Tarnation      2017.0             90.0
# 6936                                    Maniac      2011.0            160.0
# 6974                           Teeth and Blood      2015.0             96.0
# 6996                                Sugar Town      2018.0             75.0
# 7018                                 Butterfly      2010.0             90.0
# 7065              Sanctuary; Quite a Conundrum      2012.0             82.0
# 7090                             Speak No Evil      2013.0             74.0
# 7104                               The Gallows      2015.0             81.0
# 7129                         The Night Visitor      2013.0             91.0
# 7137                                  Absentia      2011.0             87.0
# 7145                                   Hayride      2012.0             93.0
# 7156                           The Anniversary      2012.0            104.0
# 7163                            Raymond Did It      2011.0             83.0
# 7166         Her Cry: La Llorona Investigation      2013.0             89.0
# 7173                                Paraphobia      2013.0             80.0
# 7182                                    Exeter      2015.0             91.0
# 7196                                The Ridges      2011.0             89.0
# 7204                                     Clean      2017.0             70.0
# 7216                                    Red 11      2019.0             77.0
# 7219                      A Plague So Pleasant      2013.0             76.0
#
#                        genres  averagerating  numvotes       studio    year  \
# 0                      Horror            6.1      43.0          NaN     NaN
# 87    Action,Adventure,Horror            7.0  553751.0    Paramount  2013.0
# 118      Action,Horror,Sci-Fi            5.7  114042.0  Warner Bros  2018.0
# 236     Comedy,Fantasy,Horror            6.2  229818.0  Warner Bros  2012.0
# 238      Drama,Fantasy,Horror            5.8   97873.0    Universal  2010.0
# 576    Horror,Sci-Fi,Thriller            6.4  226920.0          Fox  2017.0
# 736      Drama,Horror,Mystery            3.6     290.0          NaN     NaN
# 780           Horror,Thriller            5.8     688.0          NaN     NaN
# 802     Crime,Horror,Thriller            5.1     201.0          NaN     NaN
# 809                    Horror            NaN       NaN          NaN     NaN
# 995                    Horror            NaN       NaN          NaN     NaN
# 1018    Action,Fantasy,Horror            5.9  142853.0          Fox  2012.0
# 1067     Action,Horror,Sci-Fi            5.4  125191.0         SGem  2012.0
# 1081    Action,Fantasy,Horror            5.1   74910.0          LGF  2014.0
# 1210    Action,Fantasy,Horror            5.9  121936.0         SGem  2013.0
# 1248          Horror,Thriller            4.3     971.0          NaN     NaN
# 1257  Action,Adventure,Horror            5.9  153270.0         SGem  2010.0
# 1294      Action,Drama,Horror            NaN       NaN          NaN     NaN
# 1318     Action,Comedy,Horror            5.7  115757.0          Fox  2012.0
# 1328   Adventure,Drama,Horror            6.9  228664.0          NaN     NaN
# 1329     Drama,Fantasy,Horror            6.5  119287.0    Universal  2015.0
# 1436                   Horror            5.3     472.0          NaN     NaN
# 1443    Action,Fantasy,Horror            6.1  183387.0          NaN     NaN
# 1456                   Horror            NaN       NaN          NaN     NaN
# 1549                   Horror            NaN       NaN          NaN     NaN
# 1678  Horror,Mystery,Thriller            4.2     259.0          NaN     NaN
# 1740   Fantasy,Horror,Mystery            5.5  102369.0  Warner Bros  2011.0
# 1852                   Horror            5.9   98061.0  Warner Bros  2011.0
# 1860           Horror,Mystery            6.2  118779.0       W/Dim.  2011.0
# 1892     Action,Horror,Sci-Fi            5.6   74979.0         SGem  2017.0
# 1901   Comedy,Horror,Thriller            4.9      36.0          NaN     NaN
# 1945      Drama,Horror,Sci-Fi            6.0   47492.0          Fox  2015.0
# 2013    Horror,Mystery,Sci-Fi            6.2  111900.0          NaN     NaN
# 2028          Horror,Thriller            NaN       NaN          NaN     NaN
# 2032                   Horror            6.6      12.0  Warner Bros  2015.0
# 2045     Drama,Horror,Mystery            6.0   85604.0  Warner Bros  2011.0
# 2071          Horror,Thriller            7.4  359123.0  Warner Bros  2017.0
# 2086                   Horror            7.2      23.0          NaN     NaN
# 2096       Crime,Drama,Horror            5.2   85497.0          NaN     NaN
# 2110          Horror,Thriller            4.9   51538.0          NaN     NaN
# 2246  Action,Adventure,Horror            4.9   55071.0         Sum.  2011.0
# 2276     Comedy,Horror,Sci-Fi            5.9    9670.0          NaN     NaN
# 2381    Comedy,Horror,Romance            6.9  208709.0         LG/S  2013.0
# 2428                   Horror            7.0  338445.0          LGF  2012.0
# 2439          Horror,Thriller            5.0     833.0          NaN     NaN
# 2449             Drama,Horror            5.9  125424.0          NaN     NaN
# 2459  Horror,Mystery,Thriller            6.2   63793.0          NaN     NaN
# 2483            Comedy,Horror            6.4   94555.0          NaN     NaN
# 2634     Action,Comedy,Horror            5.8   46187.0         SGem  2016.0
# 2691     Drama,Horror,Mystery            5.2   33752.0          NaN     NaN
# 2694                   Horror            3.3     275.0          NaN     NaN
# 2701    Action,Fantasy,Horror            5.2   92709.0          NaN     NaN
# 2794    Action,Horror,Mystery            6.4    1287.0          NaN     NaN
# 2853     Drama,Horror,Mystery            4.5   34151.0    Paramount  2017.0
# 2858  Fantasy,Horror,Thriller            5.6   44490.0           FD  2011.0
# 2869          Horror,Thriller            4.0   23190.0        Rela.  2011.0
# 2882                   Horror            NaN       NaN    Universal  2015.0
# 2897  Horror,Mystery,Thriller            4.8   18381.0    Universal  2010.0
# 3001            Comedy,Horror            5.4   81327.0       W/Dim.  2010.0
# 3113     Drama,Horror,Mystery            6.3   64684.0          NaN     NaN
# 3127  Horror,Mystery,Thriller            6.0   34472.0          NaN     NaN
# 3155  Horror,Mystery,Thriller            5.7   40213.0          NaN     NaN
# 3167  Horror,Mystery,Thriller            7.5  397233.0  Warner Bros  2013.0
# 3241          Horror,Thriller            4.8   41784.0          LGF  2013.0
# 3281    Comedy,Fantasy,Horror            6.2     851.0          NaN     NaN
# 3329     Drama,Fantasy,Horror            7.1  107012.0        Over.  2010.0
# 3374   Fantasy,Horror,Mystery            6.8   37360.0       Amazon  2018.0
# 3405     Crime,Horror,Mystery            5.7   33335.0       W/Dim.  2016.0
# 3419      Drama,Horror,Sci-Fi            6.6  218063.0          NaN     NaN
# 3438          Horror,Thriller            6.5  104465.0        Over.  2010.0
# 3469  Horror,Mystery,Thriller            6.5      33.0          NaN     NaN
# 3494       Crime,Drama,Horror            5.6    8998.0         SGem  2015.0
# 3525     Drama,Fantasy,Horror            5.9    2396.0          NaN     NaN
# 3610    Action,Fantasy,Horror            5.3    7312.0           KE  2014.0
# 3625     Drama,Fantasy,Horror            6.2   55287.0          NaN     NaN
# 3648  Fantasy,Horror,Thriller            6.5  146399.0          NaN     NaN
# 3675          Horror,Thriller            4.1   18112.0  Warner Bros  2012.0
# 3709                   Horror            6.5      14.0          NaN     NaN
# 3716                   Horror            NaN       NaN          NaN     NaN
# 3755                   Horror            4.6      77.0         FoxS  2013.0
# 3772    Comedy,Horror,Romance            5.2    8838.0          NaN     NaN
# 3796  Horror,Mystery,Thriller            6.5   90402.0  Warner Bros  2017.0
# 3814          Horror,Thriller            6.6   88395.0          NaN     NaN
# ...
# 6155   83  Dec 31, 2012            2100000              0                0
# 6164   92  Dec 17, 1973            2000000       18344729         18344729
# 6168   94  Mar 13, 2015            2000000       14674077         23250755
# 6171   97   Mar 9, 2012            2000000       12739737         16610760
# 6218   41  Nov 28, 2014            2000000         950792          7482387
# 6250   69  Aug 27, 2010            2000000          10024            10024
# 6261   76   Sep 9, 2011            2000000              0          2151887
# 6262   77  Oct 23, 2015            2000000              0           475846
# 6264   79   Apr 1, 2013            2000000              0            63555
# 6270   82  Dec 31, 2009            2000000              0                0
# 6291   96  Mar 20, 2015            2000000              0                0
# 6293   98  Aug 21, 2015            2000000              0                0
# 6294   99  Dec 31, 2015            2000000              0                0
# 6324   15  Aug 27, 2010            1800000       41034350         70165900
# 6348   37   Oct 8, 2010            1750000          93051          1278471
# 6349   38  Apr 23, 2019            1750000              0                0
# 6360   48   Feb 1, 2019            1660000              0            80745
# 6368   56  Dec 31, 1989            1600000         419428           419428
# 6375   63   Apr 1, 2011            1500000       54009150         99870886
# 6378   65  Sep 12, 2003            1500000       21158188         30351664
# 6383   70  Mar 23, 2018            1500000        7690044         14244931
# 6387   74  Oct 31, 1945            1500000        7000000          7000000
# 6398   84  Apr 19, 2013            1500000        1165881          1541131
# 6399   85  Oct 21, 2016            1500000         779820           922727
# 6401   87  Apr 22, 2016            1500000         510957           510957
# 6420    7  Oct 17, 2014            1500000              0           236863
# 6430   16  Nov 20, 2015            1500000              0                0
# 6445   25   Apr 5, 2013            1400000           1632             1632
# 6448   28  Dec 31, 2014            1400000              0                0
# 6480   47  Mar 21, 1940            1288000        6000000          6002370
# 6488   54  Dec 31, 2016            1250000              0           726460
# 6512   77   Feb 6, 2018            1200000           8708             8708
# 6519   84   Sep 7, 2012            1200000              0                0
# 6520   85  Sep 14, 2012            1200000              0                0
# 6522   87   Feb 3, 2015            1200000              0                0
# 6523   88  Dec 31, 2013            1200000              0                0
# 6534  100  May 18, 2012            1100000          56491            56491
# 6544    7  Dec 31, 2010            1100000              0                0
# 6545    8  Dec 31, 2013            1100000              0                0
# 6550   12   Jan 6, 2012            1000000       53262945        101759490
# 6552   14  Apr 17, 2015            1000000       32789645         64364198
# 6555   17  Aug 23, 2013            1000000       18494006         26887177
# 6556   18  May 25, 2012            1000000       18119640         42411721
# 6557   19  Apr 10, 1981            1000000       17985000         17985000
# 6567   29  Jul 20, 2018            1000000        8866745         16434588
# 6569   31  Sep 25, 2015            1000000        7192291         12931420
# 6619   74   Apr 8, 2016            1000000         231738           354836
# 6660   11  Mar 20, 2012            1000000              0                0
# 6661   12   Oct 9, 2012            1000000              0                0
# 6662   13  May 14, 2013            1000000              0                0
# 6665   16   Oct 8, 2013            1000000              0                0
# 6668   19  Feb 10, 2015            1000000              0                0
# 6683   30  Jan 10, 2014             950000              0            78122
# 6692   39   Apr 1, 2016             900000        9097072          9097072
# 6723   70   Feb 3, 2012             800000          29063           462206
# 6724   71   Jan 9, 2015             800000              0                0
# 6734   78   Feb 3, 2012             750000          78396          1011535
# 6737   81   Jul 1, 2005             750000          41196           229250
# 6765  100  Oct 11, 2013             650000         171962           171962
# 6801   26  Apr 27, 1984             550000        5269990          5269990
# 6838   55   Apr 1, 2011             500000         100370           680914
# 6867   74  Jul 17, 2012             500000              0                0
# 6871   78  Mar 10, 2015             500000              0                0
# 6873   79  Apr 14, 2015             500000              0                0
# 6875   81  Feb 10, 2015             500000              0                0
# 6879   85  Dec 31, 1990             500000              0                0
# 6881   87  Aug 11, 2015             500000              0                0
# 6914   13   Oct 6, 2004             400000         592014          1162014
# 6936   28   Jan 1, 1980             350000       10000000         10000000
# 6974   63  Mar 10, 2015             300000              0                0
# 6996   82  Sep 17, 1999             250000         178095           178095
# 7018   98  Dec 31, 2010             250000              0                0
# 7065   39  Aug 26, 2014             200000              0                0
# 7090   62  Dec 31, 2013             150000              0            32927
# 7104   80  Jul 10, 2015             100000       22764410         41656474
# 7129   98  Nov 10, 2015             100000              0                0
# 7137    6  Dec 31, 2011              70000              0             8555
# 7145   13  Dec 31, 2012              60000              0                0
# 7156   25   Sep 1, 2015              50000              0                0
# 7163   32  Feb 11, 2011              40000           3632             3632
# 7166   35  Oct 25, 2013              35000              0                0
# 7173   42  Dec 31, 2013              30000              0                0
# 7182   49   Sep 1, 2015              25000              0           489792
# 7196   59  Nov 25, 2011              17300              0                0
# 7204   67  Apr 28, 2006              10000         138711           138711
# 7216   78  Dec 31, 2018               7000              0                0
# 7219   81  Sep 29, 2015               1400              0                0
#
#           profit           ROI
# 0     2351345279    553.257713
# 87     341514650    179.744553
# 118    351530715    197.489166
# 236     88202668     58.801779
# 238     -7365642     -4.910428
# 576    141521247    145.898193
# 736    155185089    188.103138
# 780     62783718     78.479647
# 802     78908290     98.635362
# 809    -26491142    -33.113928
# 995      3591500      5.130714
# 1018    69989730    103.688489
# 1067   175647629    270.227122
# 1081     9575290     14.731215
# 1210    15965567     26.609278
# 1248    29100000     50.172414
# 1257   238374190    414.563809
# 1294   143750909    261.365289
# 1318    12130045     22.054627
# 1328   -11929085    -21.689245
# 1329    19966854     36.303371
# 1436    67211892    134.423784
# 1443   164949716    329.899432
# 1456    30369970     60.739940
# 1549    23689126     48.345155
# 1678   -27507986    -61.128858
# 1740    49678442    118.282005
# 1852   115011165    287.527913
# 1860    55989590    139.973975
# 1892   274101190    685.252975
# 1901    22226214     55.565535
# 1945    -8875633    -22.189083
# 2013   -10426922    -27.439268
# 2028   -27686691    -73.831176
# 2032   136567581    369.101570
# 2045    60143987    162.551316
# 2071   662457969   1892.737054
# 2086   124846429    356.704083
# 2096    82729621    236.370346
# 2110    60713069    173.465911
# 2246    28031715     80.550905
# 2276   -32929042    -99.784976
# 2381    85121608    283.738693
# 2428    40689968    135.633227
# 2439    21078541     70.261803
# 2449    52409520    174.698400
# 2459    57956618    193.188727
# 2483    10520649     35.068830
# 2634   -11361700    -40.577500
# 2691    35308153    135.800588
# 2694    70666486    271.794177
# 2701    41647574    160.182977
# 2794    98696741    394.786964
# 2853    57917283    231.669132
# 2858    14126427     56.505708
# 2869    -6122847    -24.491388
# 2882    -1493763     -5.975052
# 2897    -8272530    -33.090120
# 3001    59660160    248.584000
# 3113    -2436421    -11.074641
# 3127    88501146    421.434029
# 3155   -21000000   -100.000000
# 3167   298000141   1490.000705
# 3241    27666013    138.330065
# 3281      268825      1.344125
# 3329     8270399     41.351995
# 3374   -12965385    -64.826925
# 3405    -4175626    -20.878130
# 3419   -19800000   -100.000000
# 3438    37445534    197.081758
# 3469   -14278659    -77.181941
# 3494    42278166    234.878700
# 3525    22651864    125.843689
# 3610   -17905047    -99.472483
# 3625    -3181116    -17.972407
# 3648    80778356    475.166800
# 3675    -6362719    -37.427759
# 3709   103739110    648.369438
# 3716    62208812    388.805075
# 3755     6594052     41.212825
# 3772   -15905188    -99.407425
# 3796   290384865   1935.899100
# 3814    62514401    416.762673
# 3819   113955898    759.705987
# 3831    46788393    311.922620
# 3913    -3385046    -22.566973
# 3956      554855      3.699033
# 3962   -11496239    -76.641593
# 4047    68925064    492.321886
# 4050    58571864    418.370457
# 4123    -6070067    -45.639602
# 4130   123617305    950.902346
# 4135   105763442    813.564938
# 4189     1929184     14.839877
# 4196    -9382723    -72.174792
# 4199    57021476    445.480281
# 4315    11477345     95.644542
# 4346    -9937594    -82.813283
# 4456   -10338636    -97.534302
# 4476   108514727   1085.147270
# 4480   157885588   1578.855880
# 4491    60133905    601.339050
# 4496    92445196    924.451960
# 4502    58220952    582.209520
# 4506    53354114    533.541140
# 4516    41723644    417.236440
# 4522    20768449    207.684490
# 4529    44104225    441.042250
# 4530    30749230    307.492300
# 4544    28985577    289.855770
# 4551    67959374    679.593740
# 4625    -1109906    -11.099060
# 4717     5037867     50.378670
# 4723    -9424629    -94.246290
# 4732   -10000000   -100.000000
# 4738   -10000000   -100.000000
# 4755    -9500000   -100.000000
# 4774   102534881   1139.276456
# 4776    74051676    822.796400
# 4781    72831866    809.242956
# 4783    35196684    391.074267
# 4784    55179495    613.105500
# 4895    28005871    350.073387
# 5010    -3940197    -52.535960
# 5021    23787727    321.455770
# 5069    29146087    416.372671
# 5082     3062896     43.755657
# 5123    -5731654    -81.880771
# 5130    37203982    539.188145
# 5141   250362920   3851.737231
# 5204    13789712    229.828533
# 5205    36785387    613.089783
# 5227    15787233    263.120550
# 5255    -4634892    -77.248200
# 5296    12619231    229.440564
# 5328    -4859179    -91.682623
# 5340   250367951   5007.359020
# 5347   202039844   4040.796880
# 5350   103286422   2065.728440
# 5361   120010260   2400.205200
# 5362   137817992   2756.359840
# 5363    98300632   1966.012640
# 5379    85904854   1718.097080
# 5382    39115496    782.309920
# 5387    33359310    667.186200
# 5390    24960051    499.201020
# 5399    16277770    325.555400
# 5411    21517819    430.356380
# 5426    14720203    294.404060
# 5443     6792942    135.858840
# 5452     1755271     35.105420
# 5463     4371036     87.420720
# 5470    -1192497    -23.849940
# 5512    -4991703    -99.834060
# 5515    -4992444    -99.848880
# 5518    -3495040    -69.900800
# 5540     2024321     41.312673
# 5550      222016      4.674021
# 5594    -3472240    -77.160889
# 5603    -4500000   -100.000000
# 5625     1635247     38.934452
# 5642    49401938   1235.048450
# 5655    21448707    536.217675
# 5660    23786849    594.671225
# 5663     6898293    172.457325
# 5693    -2016404    -50.410100
# 5726    -3320518    -83.012950
# 5731    -3952448    -98.811200
# 5773    91627344   2617.924114
# 5781    36954520   1055.843429
# 5785    24204111    691.546029
# 5863    -2509128    -78.410250
# 5866    -2976593    -96.019129
# 5868   174512032   5817.067733
# 5870    88266581   2942.219367
# 5872    84727807   2824.260233
# 5909     6012000    200.400000
# 5953    -1112446    -37.081533
# 5967    -2165047    -72.168233
# 5972    -2669000    -88.966667
# 5989    -2843638    -94.787933
# 5994     1668109     55.603633
# 6006    -3000000   -100.000000
# 6013    -3000000   -100.000000
# 6015    -3000000   -100.000000
# 6037     5500000    203.703704
# 6040    -2660000   -100.000000
# 6060    23033818    921.352720
# 6101    -2500000   -100.000000
# 6106    -2500000   -100.000000
# 6155    -2100000   -100.000000
# 6164    16344729    817.236450
# 6168    21250755   1062.537750
# 6171    14610760    730.538000
# 6218     5482387    274.119350
# 6250    -1989976    -99.498800
# 6261      151887      7.594350
# 6262    -1524154    -76.207700
# 6264    -1936445    -96.822250
# 6270    -2000000   -100.000000
# 6291    -2000000   -100.000000
# 6293    -2000000   -100.000000
# 6294    -2000000   -100.000000
# 6324    68365900   3798.105556
# 6348     -471529    -26.944514
# 6349    -1750000   -100.000000
# 6360    -1579255    -95.135843
# 6368    -1180572    -73.785750
# 6375    98370886   6558.059067
# 6378    28851664   1923.444267
# 6383    12744931    849.662067
# 6387     5500000    366.666667
# 6398       41131      2.742067
# 6399     -577273    -38.484867
# 6401     -989043    -65.936200
# 6420    -1263137    -84.209133
# 6430    -1500000   -100.000000
# 6445    -1398368    -99.883429
# 6448    -1400000   -100.000000
# 6480     4714370    366.022516
# 6488     -523540    -41.883200
# 6512    -1191292    -99.274333
# 6519    -1200000   -100.000000
# 6520    -1200000   -100.000000
# 6522    -1200000   -100.000000
# 6523    -1200000   -100.000000
# 6534    -1043509    -94.864455
# 6544    -1100000   -100.000000
# 6545    -1100000   -100.000000
# 6550   100759490  10075.949000
# 6552    63364198   6336.419800
# 6555    25887177   2588.717700
# 6556    41411721   4141.172100
# 6557    16985000   1698.500000
# 6567    15434588   1543.458800
# 6569    11931420   1193.142000
# 6619     -645164    -64.516400
# 6660    -1000000   -100.000000
# 6661    -1000000   -100.000000
# 6662    -1000000   -100.000000
# 6665    -1000000   -100.000000
# 6668    -1000000   -100.000000
# 6683     -871878    -91.776632
# 6692     8197072    910.785778
# 6723     -337794    -42.224250
# 6724     -800000   -100.000000
# 6734      261535     34.871333
# 6737     -520750    -69.433333
# 6765     -478038    -73.544308
# 6801     4719990    858.180000
# 6838      180914     36.182800
# 6867     -500000   -100.000000
# 6871     -500000   -100.000000
# 6873     -500000   -100.000000
# 6875     -500000   -100.000000
# 6879     -500000   -100.000000
# 6881     -500000   -100.000000
# 6914      762014    190.503500
# 6936     9650000   2757.142857
# 6974     -300000   -100.000000
# 6996      -71905    -28.762000
# 7018     -250000   -100.000000
# 7065     -200000   -100.000000
# 7090     -117073    -78.048667
# 7104    41556474  41556.474000
# 7129     -100000   -100.000000
# 7137      -61445    -87.778571
# 7145      -60000   -100.000000
# 7156      -50000   -100.000000
# 7163      -36368    -90.920000
# 7166      -35000   -100.000000
# 7173      -30000   -100.000000
# 7182      464792   1859.168000
# 7196      -17300   -100.000000
# 7204      128711   1287.110000
# 7216       -7000   -100.000000
# 7219       -1400   -100.000000

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Top Grossing Films

# %% [markdown]
# ### Top Grossing Films

# %% [markdown]
# We'll look at the most obvious stat first - top 25 grossing films worldwide by title.

# %%
#Hard coding to add missing values

df_replace_na = df_all3.nlargest(25,'worldwide_gross')
df_replace_na_select = df_replace_na[['title', 'genres', 'year', 'studio','worldwide_gross', 'domestic_gross']]

# Avatar
df_replace_na_select.at[df_replace_na_select.index[0], 'genres'] = 'Action,Adventure,Sci-Fi'
df_replace_na_select.at[df_replace_na_select.index[0], 'year'] = '2009'
df_replace_na_select.at[df_replace_na_select.index[0], 'studio'] = '20th Century Fox'

# Titanic
df_replace_na_select.at[df_replace_na_select.index[1], 'year'] = '1997'
df_replace_na_select.at[df_replace_na_select.index[1], 'studio'] = 'Paramount'

# Star Wars VII
df_replace_na_select.at[df_replace_na_select.index[2], 'genres'] = 'Action,Adventure,Sci-Fi'
df_replace_na_select.at[df_replace_na_select.index[2], 'year'] = '2015'
df_replace_na_select.at[df_replace_na_select.index[2], 'studio'] = 'Disney'

# The Avengers
df_replace_na_select.at[df_replace_na_select.index[6], 'year'] = '2012'
df_replace_na_select.at[df_replace_na_select.index[6], 'studio'] = 'Disney'

# Harry Potter - Deathly Hallows 2
df_replace_na_select.at[df_replace_na_select.index[9], 'genres'] = 'Action,Adventure,Sci-Fi'
df_replace_na_select.at[df_replace_na_select.index[9], 'year'] = '2011'
df_replace_na_select.at[df_replace_na_select.index[9], 'studio'] = 'Warner Bros'

# Star Wars VIII
df_replace_na_select.at[df_replace_na_select.index[10], 'genres'] = 'Action,Adventure,Sci-Fi'
df_replace_na_select.at[df_replace_na_select.index[10], 'year'] = '2017'
df_replace_na_select.at[df_replace_na_select.index[10], 'studio'] = 'Disney'

# Beauty and the Beast
df_replace_na_select.at[df_replace_na_select.index[13], 'year'] = '2017'
df_replace_na_select.at[df_replace_na_select.index[13], 'studio'] = 'Disney'

# %%
df_replace_na_select = df_replace_na_select[df_replace_na_select['year'] >= 2008]
# df_replace_na_select['year'] > 2008
df_replace_na_select
# Out:
#                                              title  \
# 0                                           Avatar
# 5             Star Wars Ep. VII: The Force Awakens
# 6                           Avengers: Infinity War
# 34                                  Jurassic World
# 85                                       Furious 7
# 26                                    The Avengers
# 3                          Avengers: Age of Ultron
# 53                                   Black Panther
# 388  Harry Potter and the Deathly Hallows: Part II
# 4                Star Wars Ep. VIII: The Last Jedi
# 149                 Jurassic World: Fallen Kingdom
# 201                                         Frozen
# 172                           Beauty and the Beast
# 56                                   Incredibles 2
# 22                         The Fate of the Furious
# 60                                      Iron Man 3
# 909                                        Minions
# 178                                        Aquaman
# 16                      Captain America: Civil War
# 81                  Transformers: Dark of the Moon
# 69                                         Skyfall
# 37                 Transformers: Age of Extinction
#
#                          genres    year            studio  worldwide_gross  \
# 0       Action,Adventure,Sci-Fi  2009.0  20th Century Fox       2776345279
# 5       Action,Adventure,Sci-Fi  2015.0            Disney       2053311220
# 6       Action,Adventure,Sci-Fi  2018.0            Disney       2048134200
# 34      Action,Adventure,Sci-Fi  2015.0         Universal       1648854864
# 85        Action,Crime,Thriller  2015.0         Universal       1518722794
# 26      Action,Adventure,Sci-Fi  2012.0            Disney       1517935897
# 3       Action,Adventure,Sci-Fi  2015.0            Disney       1403013963
# 53      Action,Adventure,Sci-Fi  2018.0            Disney       1348258224
# 388     Action,Adventure,Sci-Fi  2011.0       Warner Bros       1341693157
# 4       Action,Adventure,Sci-Fi  2017.0            Disney       1316721747
# 149     Action,Adventure,Sci-Fi  2018.0         Universal       1305772799
# 201       Adventure,Drama,Sport  2013.0            Disney       1272469910
# 172       Drama,Fantasy,Romance  2017.0            Disney       1259199706
# 56   Action,Adventure,Animation  2018.0            Disney       1242520711
# 22        Action,Crime,Thriller  2017.0         Universal       1234846267
# 60      Action,Adventure,Sci-Fi  2013.0            Disney       1215392272
# 909  Adventure,Animation,Comedy  2015.0         Universal       1160336173
# 178    Action,Adventure,Fantasy  2018.0       Warner Bros       1146894640
# 16      Action,Adventure,Sci-Fi  2016.0            Disney       1140069413
# 81      Action,Adventure,Sci-Fi  2011.0        DreamWorks       1123790543
# 69    Action,Adventure,Thriller  2012.0              Sony       1110526981
# 37      Action,Adventure,Sci-Fi  2014.0         Paramount       1104039076
#
#      domestic_gross
# 0         760507625
# 5         936662225
# 6         678815482
# 34        652270625
# 85        353007020
# 26        623279547
# 3         459005868
# 53        700059566
# 388       381193157
# 4         620181382
# 149       417719760
# 201       400738009
# 172       504014165
# 56        608581744
# 22        225764765
# 60        408992272
# 909       336045770
# 178       335061807
# 16        408084349
# 81        352390543
# 69        304360277
# 37        245439076

# %%
df_topwwg = df_replace_na_select.nlargest(15,'worldwide_gross') # top 25 films sorted by 'worldwide_gross'
df_topwwg_select = df_topwwg[['title', 'genres', 'year', 'studio','worldwide_gross', 'domestic_gross']]
df_topwwg_select
# Out:
#                                              title  \
# 0                                           Avatar
# 5             Star Wars Ep. VII: The Force Awakens
# 6                           Avengers: Infinity War
# 34                                  Jurassic World
# 85                                       Furious 7
# 26                                    The Avengers
# 3                          Avengers: Age of Ultron
# 53                                   Black Panther
# 388  Harry Potter and the Deathly Hallows: Part II
# 4                Star Wars Ep. VIII: The Last Jedi
# 149                 Jurassic World: Fallen Kingdom
# 201                                         Frozen
# 172                           Beauty and the Beast
# 56                                   Incredibles 2
# 22                         The Fate of the Furious
#
#                          genres    year            studio  worldwide_gross  \
# 0       Action,Adventure,Sci-Fi  2009.0  20th Century Fox       2776345279
# 5       Action,Adventure,Sci-Fi  2015.0            Disney       2053311220
# 6       Action,Adventure,Sci-Fi  2018.0            Disney       2048134200
# 34      Action,Adventure,Sci-Fi  2015.0         Universal       1648854864
# 85        Action,Crime,Thriller  2015.0         Universal       1518722794
# 26      Action,Adventure,Sci-Fi  2012.0            Disney       1517935897
# 3       Action,Adventure,Sci-Fi  2015.0            Disney       1403013963
# 53      Action,Adventure,Sci-Fi  2018.0            Disney       1348258224
# 388     Action,Adventure,Sci-Fi  2011.0       Warner Bros       1341693157
# 4       Action,Adventure,Sci-Fi  2017.0            Disney       1316721747
# 149     Action,Adventure,Sci-Fi  2018.0         Universal       1305772799
# 201       Adventure,Drama,Sport  2013.0            Disney       1272469910
# 172       Drama,Fantasy,Romance  2017.0            Disney       1259199706
# 56   Action,Adventure,Animation  2018.0            Disney       1242520711
# 22        Action,Crime,Thriller  2017.0         Universal       1234846267
#
#      domestic_gross
# 0         760507625
# 5         936662225
# 6         678815482
# 34        652270625
# 85        353007020
# 26        623279547
# 3         459005868
# 53        700059566
# 388       381193157
# 4         620181382
# 149       417719760
# 201       400738009
# 172       504014165
# 56        608581744
# 22        225764765

# %%
df_select = df_topwwg_select.copy()
df_select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            15 non-null     object
#  1   genres           15 non-null     object
#  2   year             15 non-null     float64
#  3   studio           15 non-null     object
#  4   worldwide_gross  15 non-null     int64
#  5   domestic_gross   15 non-null     int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 840.0+ bytes

# %%
# Create plot
fig, ax = plt.subplots(figsize = (10,12))
title = df_select['title']
ww_gross = df_select['worldwide_gross']
d_gross = df_select['domestic_gross']

ax.set_title('Top Grossing Movies - 2010 - 2018')
ax.set_xlabel('In Billions USD')

orange_patch = mpatches.Patch(color='orange', label='domestic gross')
plt.legend(handles=[orange_patch])
teal_patch = mpatches.Patch(color='teal', label='worldwide gross')
plt.legend(handles=[orange_patch, teal_patch])

Domestic = ax.barh(title, ww_gross, color = 'teal')
World = ax.barh(title, d_gross, color = 'orange')

plt.savefig('images/top_grossing_movies.pdf', dpi=300, bbox_inches = "tight")
plt.show();

# %%
# Summed values for next chart
sum_ups = df_select.groupby(['studio',]).sum('worldwide_gross').reset_index()
sum_ups = sum_ups.sort_values('worldwide_gross', ascending = False)
sum_ups
# Out:
#              studio     year  worldwide_gross  domestic_gross
# 1            Disney  18143.0      13461565578      5531337988
# 2         Universal   8065.0       5708196724      1648762170
# 0  20th Century Fox   2009.0       2776345279       760507625
# 3       Warner Bros   2011.0       1341693157       381193157

# %%
fig, ax = plt.subplots(figsize = (10,6))
studio = sum_ups['studio']
ww_gross = sum_ups['worldwide_gross']
d_gross = sum_ups['domestic_gross']

World = ax.barh(studio, ww_gross, color = 'teal')
Domestic = ax.barh(studio, d_gross, color = 'orange')

ax.set_title('Top Grossing Movie Studios - 2010 - 2018')
ax.set_xlabel('In Trillions USD')
ax.set_ylabel('Studio')

orange_patch = mpatches.Patch(color='orange', label='domestic gross')
plt.legend(handles=[orange_patch])
teal_patch = mpatches.Patch(color='teal', label='worldwide gross')
plt.legend(handles=[orange_patch, teal_patch])
          
plt.savefig('images/top_grossing_movies_by_studio.pdf', dpi=300, bbox_inches = "tight")
plt.show()
